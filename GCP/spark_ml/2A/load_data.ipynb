# %% [markdown]
# # TBD -loading data, sparkSQL, DF API

# %% [markdown]
# ## Wczytanie danych
#
# Bedziemy wykorzystywać dane z ankiety StackOverflow z 2020.
#
# https://insights.stackoverflow.com/survey/
#
# Dane sa dostepne na google drive. Skorzystamy z modułu GoogleDriveDownloader, ktory pozwala pobrac dokument o podanym id.

# %%
pip install googledrivedownloader
# Out:
# Requirement already satisfied: googledrivedownloader in /opt/conda/lib/python3.10/site-packages (0.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
from google_drive_downloader import GoogleDriveDownloader as gdd

# %%
from pathlib import Path
path_dir = str(Path.home()) + "/data/2020/"  # ustawmy sciezke na HOME/data/2020
archive_dir = path_dir + "survey.zip"        # plik zapiszemy pod nazwa survey.zip

# %%
path_dir
# Out:
# '/home/jovyan/data/2020/'

# %%
archive_dir
# Out:
# '/home/jovyan/data/2020/survey.zip'

# %%
# sciagniecie pliku we wskazane miejsce
gdd.download_file_from_google_drive(file_id='1dfGerWeWkcyQ9GX9x20rdSGj7WtEpzBB',
                                    dest_path=archive_dir,
                                    unzip=True)
# Out:
# Downloading 1dfGerWeWkcyQ9GX9x20rdSGj7WtEpzBB into /home/jovyan/data/2020/survey.zip... Done.
# Unzipping...Done.

# %% [markdown]
# ##  Podłączenie do sesji Spark

# %% [markdown]
# #### WAZNE
# jesli w poprzednim notatniku masz aktywną sesję Spark zakończ ją (w poprzednim notatniku) poleceniem spark.stop()

# %%
from pyspark.sql import SparkSession
#spark.stop()
spark = SparkSession \
.builder \
.config("spark.executor.instances", "1")\
.config('spark.driver.memory','1g')\
.config('spark.executor.memory', '1g') \
.getOrCreate()

# %% [markdown]
# ## Dostęp do danych

# %%
import os
user_name = 'jovyan'
print(user_name)
# Out:
# jovyan

# %%
# ścieżka dostępu do pliku
csv_path = 'file:////home/jovyan/data/2020/survey_results_public.csv'

# %%
csv_path
# Out:
# 'file:////home/jovyan/data/2020/survey_results_public.csv'

# %% [markdown]
# ## Spark SQL
#
# Platforma Apache Spark posiada komponent Spark SQL, który pozwala traktować dane jak tabele w bazie danych. Można zakładać swoje schematy baz danych oraz korzystać z języka SQL.

# %%
table_name = "survey_2020"                               # nazwa tabeli ktora bedziemy chcieli stworzyc

# %%
spark.sql(f'DROP TABLE IF EXISTS {table_name}')       # usun te tabele jesli istniala wczesniej 

# stworz tabele korzystajac z danych we wskazanej lokalizacji
spark.sql(f'CREATE TABLE IF NOT EXISTS {table_name} \
          USING csv \
          OPTIONS (HEADER true, INFERSCHEMA true, NULLVALUE "NA") \
          LOCATION "{csv_path}"')
# Out:
# DataFrame[]

# %% [markdown]
# ## Weryfikacja danych
# Sprawdzmy zaczytane dane.

# %%
spark.sql(f"describe {table_name}").show(100, truncate=False) # niepoprawne typy danych... "NA"
# Out:
# +----------------------------+---------+-------+
# |col_name                    |data_type|comment|
# +----------------------------+---------+-------+
# |Respondent                  |int      |null   |
# |MainBranch                  |string   |null   |
# |Hobbyist                    |string   |null   |
# |Age                         |double   |null   |
# |Age1stCode                  |string   |null   |
# |CompFreq                    |string   |null   |
# |CompTotal                   |double   |null   |
# |ConvertedComp               |double   |null   |
# |Country                     |string   |null   |
# |CurrencyDesc                |string   |null   |
# |CurrencySymbol              |string   |null   |
# |DatabaseDesireNextYear      |string   |null   |
# |DatabaseWorkedWith          |string   |null   |
# |DevType                     |string   |null   |
# |EdLevel                     |string   |null   |
# |Employment                  |string   |null   |
# |Ethnicity                   |string   |null   |
# |Gender                      |string   |null   |
# |JobFactors                  |string   |null   |
# |JobSat                      |string   |null   |
# |JobSeek                     |string   |null   |
# |LanguageDesireNextYear      |string   |null   |
# |LanguageWorkedWith          |string   |null   |
# |MiscTechDesireNextYear      |string   |null   |
# |MiscTechWorkedWith          |string   |null   |
# |NEWCollabToolsDesireNextYear|string   |null   |
# |NEWCollabToolsWorkedWith    |string   |null   |
# |NEWDevOps                   |string   |null   |
# |NEWDevOpsImpt               |string   |null   |
# |NEWEdImpt                   |string   |null   |
# |NEWJobHunt                  |string   |null   |
# |NEWJobHuntResearch          |string   |null   |
# |NEWLearn                    |string   |null   |
# |NEWOffTopic                 |string   |null   |
# |NEWOnboardGood              |string   |null   |
# |NEWOtherComms               |string   |null   |
# |NEWOvertime                 |string   |null   |
# |NEWPurchaseResearch         |string   |null   |
# |NEWPurpleLink               |string   |null   |
# |NEWSOSites                  |string   |null   |
# |NEWStuck                    |string   |null   |
# |OpSys                       |string   |null   |
# |OrgSize                     |string   |null   |
# |PlatformDesireNextYear      |string   |null   |
# |PlatformWorkedWith          |string   |null   |
# |PurchaseWhat                |string   |null   |
# |Sexuality                   |string   |null   |
# |SOAccount                   |string   |null   |
# |SOComm                      |string   |null   |
# |SOPartFreq                  |string   |null   |
# |SOVisitFreq                 |string   |null   |
# |SurveyEase                  |string   |null   |
# |SurveyLength                |string   |null   |
# |Trans                       |string   |null   |
# |UndergradMajor              |string   |null   |
# |WebframeDesireNextYear      |string   |null   |
# |WebframeWorkedWith          |string   |null   |
# |WelcomeChange               |string   |null   |
# |WorkWeekHrs                 |double   |null   |
# |YearsCode                   |string   |null   |
# |YearsCodePro                |string   |null   |
# +----------------------------+---------+-------+

# %%
# sprawdzenie liczności tabeli
spark.sql(f"select count(*) from {table_name}").show()
# Out:
# +--------+
# |count(1)|
# +--------+
# |   64461|
# +--------+

# %% [markdown]
# ## Podgląd danych

# %% [markdown]
# ## Dataframe spark vs pandas
#
# Moduł Pandas jest biblioteką Pythonową do manipulacji danymi. W szczegolnosci w pandas mozemy stworzyc ramki danych i wykonywac na niej analize, agregacje oraz wizualizacje danych.
# Przy nieduzych zbiorach danych i prostych operacjach to doskonała biblioteka. Jednak kiedy zbior danych sie rozrasta lub kiedy wymagane sa zlozone transformacje to operacje moga byc wolne.
#
# Operacje na rozproszonych danych sa szybsze. Ale tu takze napotykamy ograniczenia np trudność w wizualizacji danych.

# %%
import pandas as pd

# %%
spark.sql(f"select * from {table_name} limit 10").toPandas()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1                     I am a developer by profession      Yes
# 1           2                     I am a developer by profession       No
# 2           3                        I code primarily as a hobby      Yes
# 3           4                     I am a developer by profession      Yes
# 4           5  I used to be a developer by profession, but no...      Yes
# 5           6                     I am a developer by profession       No
# 6           7                     I am a developer by profession      Yes
# 7           8                     I am a developer by profession      Yes
# 8           9                     I am a developer by profession       No
# 9          10                     I am a developer by profession      Yes
#
#     Age Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# 0   NaN         13  Monthly        NaN            NaN             Germany
# 1   NaN         19     None        NaN            NaN      United Kingdom
# 2   NaN         15     None        NaN            NaN  Russian Federation
# 3  25.0         18     None        NaN            NaN             Albania
# 4  31.0         16     None        NaN            NaN       United States
# 5   NaN         14     None        NaN            NaN             Germany
# 6   NaN         18  Monthly        NaN            NaN               India
# 7  36.0         12   Yearly   116000.0       116000.0       United States
# 8  30.0         20     None        NaN            NaN             Tunisia
# 9  22.0         14   Yearly    25000.0        32315.0      United Kingdom
#
#            CurrencyDesc  ...                  SurveyEase  \
# 0         European Euro  ...  Neither easy nor difficult
# 1        Pound sterling  ...                        None
# 2                  None  ...  Neither easy nor difficult
# 3          Albanian lek  ...                        None
# 4                  None  ...                        Easy
# 5         European Euro  ...  Neither easy nor difficult
# 6  United States dollar  ...                        None
# 7  United States dollar  ...                        Easy
# 8  United States dollar  ...  Neither easy nor difficult
# 9        Pound sterling  ...                        Easy
#
#             SurveyLength Trans  \
# 0  Appropriate in length    No
# 1                   None  None
# 2  Appropriate in length  None
# 3                   None    No
# 4              Too short    No
# 5  Appropriate in length  None
# 6                   None  None
# 7  Appropriate in length    No
# 8  Appropriate in length    No
# 9  Appropriate in length    No
#
#                                       UndergradMajor  WebframeDesireNextYear  \
# 0  Computer science, computer engineering, or sof...            ASP.NET Core
# 1  Computer science, computer engineering, or sof...                    None
# 2                                               None                    None
# 3  Computer science, computer engineering, or sof...                    None
# 4  Computer science, computer engineering, or sof...    Django;Ruby on Rails
# 5                                               None                React.js
# 6  Computer science, computer engineering, or sof...                    None
# 7  Computer science, computer engineering, or sof...  Django;React.js;Vue.js
# 8  Computer science, computer engineering, or sof...              Angular.js
# 9                          Mathematics or statistics            Flask;jQuery
#
#      WebframeWorkedWith                             WelcomeChange WorkWeekHrs  \
# 0  ASP.NET;ASP.NET Core   Just as welcome now as I felt last year        50.0
# 1                  None  Somewhat more welcome now than last year         NaN
# 2                  None  Somewhat more welcome now than last year         NaN
# 3                  None  Somewhat less welcome now than last year        40.0
# 4         Ruby on Rails   Just as welcome now as I felt last year         NaN
# 5                  None                                      None         NaN
# 6                  None     A lot more welcome now than last year         NaN
# 7                 Flask   Just as welcome now as I felt last year        39.0
# 8                jQuery   Just as welcome now as I felt last year        50.0
# 9          Flask;jQuery  Somewhat more welcome now than last year        36.0
#
#   YearsCode YearsCodePro
# 0        36           27
# 1         7            4
# 2         4         None
# 3         7            4
# 4        15            8
# 5         6            4
# 6         6            4
# 7        17           13
# 8         6            4
# 9         8            4
#
# [10 rows x 61 columns]

# %% [markdown]
# **Ważne**
#
# Metoda toPandas() na ramce pyspark, konwertuje ramkę pyspark do ramki pandas. Wykonuje akcje pobrania (collect) wszystkich danych z executorów (z JVM) i transfer do  programu sterujacego (driver) i konwersje do typu Pythonowego w notatniku. Ze względu na ograniczenia pamięciowe w programie sterującym należy to wykonywać na podzbiorach danych.
#
# **DataFrame.collect() collects the distributed data to the driver side as the local data in Python. Note that this can throw an out-of-memory error when the dataset is too large to fit in the driver side because it collects all the data from executors to the driver side.**
#
# **Note that DataFrame.toPandas() results in the collection of all records in the DataFrame to the driver program and should be done on a small subset of the data.**

# %%
dist_df = spark.sql(f"select * from {table_name} LIMIT 10")
local_df = spark.sql(f"select * from {table_name} LIMIT 10").toPandas()

# %%
type(dist_df)  # dataframe Sparkowy ("przepis na dane, rozproszony, leniwy")
# Out:
# pyspark.sql.dataframe.DataFrame

# %%
type(local_df)  # dataframe Pandasowy (lokalny, sciągnięty do pamięci operacyjnej)
# Out:
# pandas.core.frame.DataFrame

# %%
#dist_df.show()

# %%
local_df
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1                     I am a developer by profession      Yes
# 1           2                     I am a developer by profession       No
# 2           3                        I code primarily as a hobby      Yes
# 3           4                     I am a developer by profession      Yes
# 4           5  I used to be a developer by profession, but no...      Yes
# 5           6                     I am a developer by profession       No
# 6           7                     I am a developer by profession      Yes
# 7           8                     I am a developer by profession      Yes
# 8           9                     I am a developer by profession       No
# 9          10                     I am a developer by profession      Yes
#
#     Age Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# 0   NaN         13  Monthly        NaN            NaN             Germany
# 1   NaN         19     None        NaN            NaN      United Kingdom
# 2   NaN         15     None        NaN            NaN  Russian Federation
# 3  25.0         18     None        NaN            NaN             Albania
# 4  31.0         16     None        NaN            NaN       United States
# 5   NaN         14     None        NaN            NaN             Germany
# 6   NaN         18  Monthly        NaN            NaN               India
# 7  36.0         12   Yearly   116000.0       116000.0       United States
# 8  30.0         20     None        NaN            NaN             Tunisia
# 9  22.0         14   Yearly    25000.0        32315.0      United Kingdom
#
#            CurrencyDesc  ...                  SurveyEase  \
# 0         European Euro  ...  Neither easy nor difficult
# 1        Pound sterling  ...                        None
# 2                  None  ...  Neither easy nor difficult
# 3          Albanian lek  ...                        None
# 4                  None  ...                        Easy
# 5         European Euro  ...  Neither easy nor difficult
# 6  United States dollar  ...                        None
# 7  United States dollar  ...                        Easy
# 8  United States dollar  ...  Neither easy nor difficult
# 9        Pound sterling  ...                        Easy
#
#             SurveyLength Trans  \
# 0  Appropriate in length    No
# 1                   None  None
# 2  Appropriate in length  None
# 3                   None    No
# 4              Too short    No
# 5  Appropriate in length  None
# 6                   None  None
# 7  Appropriate in length    No
# 8  Appropriate in length    No
# 9  Appropriate in length    No
#
#                                       UndergradMajor  WebframeDesireNextYear  \
# 0  Computer science, computer engineering, or sof...            ASP.NET Core
# 1  Computer science, computer engineering, or sof...                    None
# 2                                               None                    None
# 3  Computer science, computer engineering, or sof...                    None
# 4  Computer science, computer engineering, or sof...    Django;Ruby on Rails
# 5                                               None                React.js
# 6  Computer science, computer engineering, or sof...                    None
# 7  Computer science, computer engineering, or sof...  Django;React.js;Vue.js
# 8  Computer science, computer engineering, or sof...              Angular.js
# 9                          Mathematics or statistics            Flask;jQuery
#
#      WebframeWorkedWith                             WelcomeChange WorkWeekHrs  \
# 0  ASP.NET;ASP.NET Core   Just as welcome now as I felt last year        50.0
# 1                  None  Somewhat more welcome now than last year         NaN
# 2                  None  Somewhat more welcome now than last year         NaN
# 3                  None  Somewhat less welcome now than last year        40.0
# 4         Ruby on Rails   Just as welcome now as I felt last year         NaN
# 5                  None                                      None         NaN
# 6                  None     A lot more welcome now than last year         NaN
# 7                 Flask   Just as welcome now as I felt last year        39.0
# 8                jQuery   Just as welcome now as I felt last year        50.0
# 9          Flask;jQuery  Somewhat more welcome now than last year        36.0
#
#   YearsCode YearsCodePro
# 0        36           27
# 1         7            4
# 2         4         None
# 3         7            4
# 4        15            8
# 5         6            4
# 6         6            4
# 7        17           13
# 8         6            4
# 9         8            4
#
# [10 rows x 61 columns]

# %%
pd.set_option('display.max_columns', None)    # pokazuj wszystkie kolumny
#pd.reset_option('max_columns')

# %% [markdown]
# ## Przykład wykorzystania Spark'a do wizualizacji
# ### Narysuj histogram wieku respondentów

# %%
# przygotowanie danych
# przycinamy dane tylko do zakresu ktory jest potrzebny do realizacji polecenia
ages = spark.sql(f"SELECT CAST (Age AS INT) \
                    FROM {table_name} \
                    WHERE age IS NOT NULL \
                    AND age BETWEEN 10 AND 80").toPandas()

# %%
ages
# Out:
#        Age
# 0       25
# 1       31
# 2       36
# 3       30
# 4       22
# ...    ...
# 45403   22
# 45404   34
# 45405   38
# 45406   64
# 45407   17
#
# [45408 rows x 1 columns]

# %%
ages.hist("Age", bins=10)
# plt.show()
# Out:
# array([[<AxesSubplot: title={'center': 'Age'}>]], dtype=object)

# %% [markdown]
# ## Spark DF API

# %%
df = spark.read.csv(csv_path, inferSchema=True, header="true", nullValue='NA', nanValue='NA',emptyValue='NA')

# %%
type (df)                 # jaki jest typ danych
# Out:
# pyspark.sql.dataframe.DataFrame

# %%
df.describe()
# Out:
# DataFrame[summary: string, Respondent: string, MainBranch: string, Hobbyist: string, Age: string, Age1stCode: string, CompFreq: string, CompTotal: string, ConvertedComp: string, Country: string, CurrencyDesc: string, CurrencySymbol: string, DatabaseDesireNextYear: string, DatabaseWorkedWith: string, DevType: string, EdLevel: string, Employment: string, Ethnicity: string, Gender: string, JobFactors: string, JobSat: string, JobSeek: string, LanguageDesireNextYear: string, LanguageWorkedWith: string, MiscTechDesireNextYear: string, MiscTechWorkedWith: string, NEWCollabToolsDesireNextYear: string, NEWCollabToolsWorkedWith: string, NEWDevOps: string, NEWDevOpsImpt: string, NEWEdImpt: string, NEWJobHunt: string, NEWJobHuntResearch: string, NEWLearn: string, NEWOffTopic: string, NEWOnboardGood: string, NEWOtherComms: string, NEWOvertime: string, NEWPurchaseResearch: string, NEWPurpleLink: string, NEWSOSites: string, NEWStuck: string, OpSys: string, OrgSize: string, PlatformDesireNextYear: string, PlatformWorkedWith: string, PurchaseWhat: string, Sexuality: string, SOAccount: string, SOComm: string, SOPartFreq: string, SOVisitFreq: string, SurveyEase: string, SurveyLength: string, Trans: string, UndergradMajor: string, WebframeDesireNextYear: string, WebframeWorkedWith: string, WelcomeChange: string, WorkWeekHrs: string, YearsCode: string, YearsCodePro: string]

# %%
df.explain()              # fizyczny plan wykonania
# Out:
# == Physical Plan ==
# FileScan csv [Respondent#494,MainBranch#495,Hobbyist#496,Age#497,Age1stCode#498,CompFreq#499,CompTotal#500,ConvertedComp#501,Country#502,CurrencyDesc#503,CurrencySymbol#504,DatabaseDesireNextYear#505,DatabaseWorkedWith#506,DevType#507,EdLevel#508,Employment#509,Ethnicity#510,Gender#511,JobFactors#512,JobSat#513,JobSeek#514,LanguageDesireNextYear#515,LanguageWorkedWith#516,MiscTechDesireNextYear#517,... 37 more fields] Batched: false, DataFilters: [], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/home/jovyan/data/2020/survey_results_public.csv], PartitionFilters: [], PushedFilters: [], ReadSchema: struct<Respondent:int,MainBranch:string,Hobbyist:string,Age:double,Age1stCode:string,CompFreq:str...

# %%
df.explain(True)          # logiczny i fizyczny plan wykonania
# Out:
# == Parsed Logical Plan ==
# Relation [Respondent#494,MainBranch#495,Hobbyist#496,Age#497,Age1stCode#498,CompFreq#499,CompTotal#500,ConvertedComp#501,Country#502,CurrencyDesc#503,CurrencySymbol#504,DatabaseDesireNextYear#505,DatabaseWorkedWith#506,DevType#507,EdLevel#508,Employment#509,Ethnicity#510,Gender#511,JobFactors#512,JobSat#513,JobSeek#514,LanguageDesireNextYear#515,LanguageWorkedWith#516,MiscTechDesireNextYear#517,... 37 more fields] csv
#
# == Analyzed Logical Plan ==
# Respondent: int, MainBranch: string, Hobbyist: string, Age: double, Age1stCode: string, CompFreq: string, CompTotal: double, ConvertedComp: double, Country: string, CurrencyDesc: string, CurrencySymbol: string, DatabaseDesireNextYear: string, DatabaseWorkedWith: string, DevType: string, EdLevel: string, Employment: string, Ethnicity: string, Gender: string, JobFactors: string, JobSat: string, JobSeek: string, LanguageDesireNextYear: string, LanguageWorkedWith: string, MiscTechDesireNextYear: string, ... 37 more fields
# Relation [Respondent#494,MainBranch#495,Hobbyist#496,Age#497,Age1stCode#498,CompFreq#499,CompTotal#500,ConvertedComp#501,Country#502,CurrencyDesc#503,CurrencySymbol#504,DatabaseDesireNextYear#505,DatabaseWorkedWith#506,DevType#507,EdLevel#508,Employment#509,Ethnicity#510,Gender#511,JobFactors#512,JobSat#513,JobSeek#514,LanguageDesireNextYear#515,LanguageWorkedWith#516,MiscTechDesireNextYear#517,... 37 more fields] csv
#
# == Optimized Logical Plan ==
# Relation [Respondent#494,MainBranch#495,Hobbyist#496,Age#497,Age1stCode#498,CompFreq#499,CompTotal#500,ConvertedComp#501,Country#502,CurrencyDesc#503,CurrencySymbol#504,DatabaseDesireNextYear#505,DatabaseWorkedWith#506,DevType#507,EdLevel#508,Employment#509,Ethnicity#510,Gender#511,JobFactors#512,JobSat#513,JobSeek#514,LanguageDesireNextYear#515,LanguageWorkedWith#516,MiscTechDesireNextYear#517,... 37 more fields] csv
#
# == Physical Plan ==
# FileScan csv [Respondent#494,MainBranch#495,Hobbyist#496,Age#497,Age1stCode#498,CompFreq#499,CompTotal#500,ConvertedComp#501,Country#502,CurrencyDesc#503,CurrencySymbol#504,DatabaseDesireNextYear#505,DatabaseWorkedWith#506,DevType#507,EdLevel#508,Employment#509,Ethnicity#510,Gender#511,JobFactors#512,JobSat#513,JobSeek#514,LanguageDesireNextYear#515,LanguageWorkedWith#516,MiscTechDesireNextYear#517,... 37 more fields] Batched: false, DataFilters: [], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/home/jovyan/data/2020/survey_results_public.csv], PartitionFilters: [], PushedFilters: [], ReadSchema: struct<Respondent:int,MainBranch:string,Hobbyist:string,Age:double,Age1stCode:string,CompFreq:str...

# %%
df.rdd.getNumPartitions() # liczba partycji (bloków danych)
# Out:
# 4

# %%
df.printSchema()          # schemat danych
# Out:
# root
#  |-- Respondent: integer (nullable = true)
#  |-- MainBranch: string (nullable = true)
#  |-- Hobbyist: string (nullable = true)
#  |-- Age: double (nullable = true)
#  |-- Age1stCode: string (nullable = true)
#  |-- CompFreq: string (nullable = true)
#  |-- CompTotal: double (nullable = true)
#  |-- ConvertedComp: double (nullable = true)
#  |-- Country: string (nullable = true)
#  |-- CurrencyDesc: string (nullable = true)
#  |-- CurrencySymbol: string (nullable = true)
#  |-- DatabaseDesireNextYear: string (nullable = true)
#  |-- DatabaseWorkedWith: string (nullable = true)
#  |-- DevType: string (nullable = true)
#  |-- EdLevel: string (nullable = true)
#  |-- Employment: string (nullable = true)
#  |-- Ethnicity: string (nullable = true)
#  |-- Gender: string (nullable = true)
#  |-- JobFactors: string (nullable = true)
#  |-- JobSat: string (nullable = true)
#  |-- JobSeek: string (nullable = true)
#  |-- LanguageDesireNextYear: string (nullable = true)
#  |-- LanguageWorkedWith: string (nullable = true)
#  |-- MiscTechDesireNextYear: string (nullable = true)
#  |-- MiscTechWorkedWith: string (nullable = true)
#  |-- NEWCollabToolsDesireNextYear: string (nullable = true)
#  |-- NEWCollabToolsWorkedWith: string (nullable = true)
#  |-- NEWDevOps: string (nullable = true)
#  |-- NEWDevOpsImpt: string (nullable = true)
#  |-- NEWEdImpt: string (nullable = true)
#  |-- NEWJobHunt: string (nullable = true)
#  |-- NEWJobHuntResearch: string (nullable = true)
#  |-- NEWLearn: string (nullable = true)
#  |-- NEWOffTopic: string (nullable = true)
#  |-- NEWOnboardGood: string (nullable = true)
#  |-- NEWOtherComms: string (nullable = true)
#  |-- NEWOvertime: string (nullable = true)
#  |-- NEWPurchaseResearch: string (nullable = true)
#  |-- NEWPurpleLink: string (nullable = true)
#  |-- NEWSOSites: string (nullable = true)
#  |-- NEWStuck: string (nullable = true)
#  |-- OpSys: string (nullable = true)
#  |-- OrgSize: string (nullable = true)
#  |-- PlatformDesireNextYear: string (nullable = true)
#  |-- PlatformWorkedWith: string (nullable = true)
#  |-- PurchaseWhat: string (nullable = true)
#  |-- Sexuality: string (nullable = true)
#  |-- SOAccount: string (nullable = true)
#  |-- SOComm: string (nullable = true)
#  |-- SOPartFreq: string (nullable = true)
#  |-- SOVisitFreq: string (nullable = true)
#  |-- SurveyEase: string (nullable = true)
#  |-- SurveyLength: string (nullable = true)
#  |-- Trans: string (nullable = true)
#  |-- UndergradMajor: string (nullable = true)
#  |-- WebframeDesireNextYear: string (nullable = true)
#  |-- WebframeWorkedWith: string (nullable = true)
#  |-- WelcomeChange: string (nullable = true)
#  |-- WorkWeekHrs: double (nullable = true)
#  |-- YearsCode: string (nullable = true)
#  |-- YearsCodePro: string (nullable = true)

# %%
df.count()                # wymiary (liczba wierszy)
# Out:
# 64461

# %%
len(df.columns)           # wymiary (liczba kolumn)
# Out:
# 61

# %%
df.describe().show()      # pokaż podsumowanie danych w tabeli
# Out:
# +-------+------------------+--------------------+--------+-----------------+--------------------+--------+--------------------+------------------+-----------+----------------+--------------+----------------------+------------------+--------------------+--------------------+------------------+--------------------+--------------------+--------------------+--------------------+--------------------+----------------------+------------------+----------------------+------------------+----------------------------+------------------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+-----------+--------------+-------------+--------------------+--------------------+-------------+--------------------+--------------------+-------+--------------------+----------------------+------------------+--------------------+--------------------+---------+-------------+--------------------+--------------------+--------------------+--------------------+-----+--------------------+----------------------+------------------+--------------------+------------------+------------------+------------------+
# |summary|        Respondent|          MainBranch|Hobbyist|              Age|          Age1stCode|CompFreq|           CompTotal|     ConvertedComp|    Country|    CurrencyDesc|CurrencySymbol|DatabaseDesireNextYear|DatabaseWorkedWith|             DevType|             EdLevel|        Employment|           Ethnicity|              Gender|          JobFactors|              JobSat|             JobSeek|LanguageDesireNextYear|LanguageWorkedWith|MiscTechDesireNextYear|MiscTechWorkedWith|NEWCollabToolsDesireNextYear|NEWCollabToolsWorkedWith|NEWDevOps|      NEWDevOpsImpt|           NEWEdImpt|          NEWJobHunt|  NEWJobHuntResearch|            NEWLearn|NEWOffTopic|NEWOnboardGood|NEWOtherComms|         NEWOvertime| NEWPurchaseResearch|NEWPurpleLink|          NEWSOSites|            NEWStuck|  OpSys|             OrgSize|PlatformDesireNextYear|PlatformWorkedWith|        PurchaseWhat|           Sexuality|SOAccount|       SOComm|          SOPartFreq|         SOVisitFreq|          SurveyEase|        SurveyLength|Trans|      UndergradMajor|WebframeDesireNextYear|WebframeWorkedWith|       WelcomeChange|       WorkWeekHrs|         YearsCode|      YearsCodePro|
# +-------+------------------+--------------------+--------+-----------------+--------------------+--------+--------------------+------------------+-----------+----------------+--------------+----------------------+------------------+--------------------+--------------------+------------------+--------------------+--------------------+--------------------+--------------------+--------------------+----------------------+------------------+----------------------+------------------+----------------------------+------------------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+-----------+--------------+-------------+--------------------+--------------------+-------------+--------------------+--------------------+-------+--------------------+----------------------+------------------+--------------------+--------------------+---------+-------------+--------------------+--------------------+--------------------+--------------------+-----+--------------------+----------------------+------------------+--------------------+------------------+------------------+------------------+
# |  count|             64461|               64162|   64416|            45446|               57900|   40069|               34826|             34756|      64072|           45472|         45472|                 44070|             49537|               49370|               57431|             63854|               45948|               50557|               49349|               45194|               51727|                 54113|             57378|                 42379|             40314|                       47287|                   52883|    42686|              41732|               48465|               42286|               41022|               56156|      50804|         42623|        57205|               43231|               37321|        54803|               58275|               54983|  56228|               44334|                 50605|             53843|               39364|               43992|    56805|        56476|               46792|               56970|               51802|               51701|49345|               50995|                 40024|             42279|               52683|             41151|             57684|             46349|
# |   mean| 32554.07973813624|                null|    null|30.83411081283281|  15.476571607537453|    null|3.190464340180066...|103756.05014961446|       null|            null|          null|                  null|              null|                null|                null|              null|                null|                null|                null|                null|                null|                  null|              null|                  null|              null|                        null|                    null|     null|               null|                null|                null|                null|                null|       null|          null|         null|                null|                null|         null|                null|                null|   null|                null|                  null|              null|                null|                null|     null|         null|                null|                null|                null|                null| null|                null|                  null|              null|                null| 40.78217399901455|12.782051282051283| 8.869666689325449|
# | stddev|18967.442359929824|                null|    null| 9.58539232884474|   5.114081176015281|    null|            Infinity|226885.29624346833|       null|            null|          null|                  null|              null|                null|                null|              null|                null|                null|                null|                null|                null|                  null|              null|                  null|              null|                        null|                    null|     null|               null|                null|                null|                null|                null|       null|          null|         null|                null|                null|         null|                null|                null|   null|                null|                  null|              null|                null|                null|     null|         null|                null|                null|                null|                null| null|                null|                  null|              null|                null|17.816383421991524|  9.49065691445291| 7.759960871149197|
# |    min|                 1|I am a developer ...|      No|              1.0|                  10| Monthly|                 0.0|               0.0|Afghanistan|  Afghan afghani|           AED|             Cassandra|         Cassandra| Academic researcher|Associate degree ...|Employed full-time|            Biracial|                 Man|Diversity of the ...|Neither satisfied...|I am actively loo...|              Assembly|          Assembly|                  .NET|              .NET|                  Confluence|              Confluence|       No|Extremely important|Critically important| Better compensation|Company reviews f...|    Every few months|         No|            No|           No|               Never|Ask developers I ...|       Amused|I have never visi...|Call a coworker o...|    BSD|1,000 to 4,999 em...|                   AWS|               AWS|I have a great de...|            Bisexual|       No|      Neutral|A few times per m...|A few times per m...|           Difficult|Appropriate in le...|   No|A business discip...|               ASP.NET|           ASP.NET|A lot less welcom...|               1.0|                 1|                 1|
# |    max|             65639|I used to be a de...|     Yes|            279.0|Younger than 5 years|  Yearly|1.11111111111111E247|         2000000.0|   Zimbabwe|e\tFaroese krona|           non|                SQLite|            SQLite|System administrator|Some college/univ...|           Student|White or of Europ...|Woman;Non-binary,...|Specific departme...|      Very satisfied|I’m not actively ...|                   VBA|               VBA|               Xamarin|           Xamarin|        Trello;Stack Over...|    Trello;Stack Over...|      Yes| Somewhat important|      Very important|Wanting to work w...|Read other media ...|Once every few years|        Yes|           Yes|          Yes|Sometimes: 1-2 da...|Visit developer c...|  Indifferent|Stack Overflow fo...|Watch help / tuto...|Windows|Just me - I am a ...|         iOS;WordPress|     iOS;WordPress|I have some influ...|Straight / Hetero...|      Yes|Yes, somewhat|Multiple times pe...|Multiple times pe...|Neither easy nor ...|           Too short|  Yes|Web development o...|         jQuery;Vue.js|     jQuery;Vue.js|Somewhat more wel...|             475.0|More than 50 years|More than 50 years|
# +-------+------------------+--------------------+--------+-----------------+--------------------+--------+--------------------+------------------+-----------+----------------+--------------+----------------------+------------------+--------------------+--------------------+------------------+--------------------+--------------------+--------------------+--------------------+--------------------+----------------------+------------------+----------------------+------------------+----------------------------+------------------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+-----------+--------------+-------------+--------------------+--------------------+-------------+--------------------+--------------------+-------+--------------------+----------------------+------------------+--------------------+--------------------+---------+-------------+--------------------+--------------------+--------------------+--------------------+-----+--------------------+----------------------+------------------+--------------------+------------------+------------------+------------------+

# %%
df.describe("Age").show() # pokaż podsumowanie danych w kolumnie
# Out:
# +-------+-----------------+
# |summary|              Age|
# +-------+-----------------+
# |  count|            45446|
# |   mean|30.83411081283281|
# | stddev| 9.58539232884474|
# |    min|              1.0|
# |    max|            279.0|
# +-------+-----------------+

# %%
df.show()                 # pokaż 20 wierszy danych
# Out:
# +----------+--------------------+--------+----+----------+--------+---------+-------------+------------------+--------------------+--------------+----------------------+--------------------+--------------------+--------------------+--------------------+--------------------+------+--------------------+--------------------+--------------------+----------------------+--------------------+----------------------+--------------------+----------------------------+------------------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+-----------+--------------------+-------------+--------------------+--------------------+-----------------+--------------------+--------------------+-----------+--------------------+----------------------+--------------------+--------------------+--------------------+---------+---------------+--------------------+--------------------+--------------------+--------------------+-----+--------------------+----------------------+--------------------+--------------------+-----------+---------+------------+
# |Respondent|          MainBranch|Hobbyist| Age|Age1stCode|CompFreq|CompTotal|ConvertedComp|           Country|        CurrencyDesc|CurrencySymbol|DatabaseDesireNextYear|  DatabaseWorkedWith|             DevType|             EdLevel|          Employment|           Ethnicity|Gender|          JobFactors|              JobSat|             JobSeek|LanguageDesireNextYear|  LanguageWorkedWith|MiscTechDesireNextYear|  MiscTechWorkedWith|NEWCollabToolsDesireNextYear|NEWCollabToolsWorkedWith|NEWDevOps|      NEWDevOpsImpt|           NEWEdImpt|          NEWJobHunt|  NEWJobHuntResearch|            NEWLearn|NEWOffTopic|      NEWOnboardGood|NEWOtherComms|         NEWOvertime| NEWPurchaseResearch|    NEWPurpleLink|          NEWSOSites|            NEWStuck|      OpSys|             OrgSize|PlatformDesireNextYear|  PlatformWorkedWith|        PurchaseWhat|           Sexuality|SOAccount|         SOComm|          SOPartFreq|         SOVisitFreq|          SurveyEase|        SurveyLength|Trans|      UndergradMajor|WebframeDesireNextYear|  WebframeWorkedWith|       WelcomeChange|WorkWeekHrs|YearsCode|YearsCodePro|
# +----------+--------------------+--------+----+----------+--------+---------+-------------+------------------+--------------------+--------------+----------------------+--------------------+--------------------+--------------------+--------------------+--------------------+------+--------------------+--------------------+--------------------+----------------------+--------------------+----------------------+--------------------+----------------------------+------------------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+-----------+--------------------+-------------+--------------------+--------------------+-----------------+--------------------+--------------------+-----------+--------------------+----------------------+--------------------+--------------------+--------------------+---------+---------------+--------------------+--------------------+--------------------+--------------------+-----+--------------------+----------------------+--------------------+--------------------+-----------+---------+------------+
# |         1|I am a developer ...|     Yes|null|        13| Monthly|     null|         null|           Germany|       European Euro|           EUR|  Microsoft SQL Server|Elasticsearch;Mic...|Developer, deskto...|Master’s degree (...|Independent contr...|White or of Europ...|   Man|Languages, framew...|  Slightly satisfied|I am not interest...|  C#;HTML/CSS;JavaS...|C#;HTML/CSS;JavaS...|     .NET Core;Xamarin|      .NET;.NET Core|        Microsoft Teams;M...|    Confluence;Jira;S...|       No| Somewhat important|    Fairly important|                null|                null|         Once a year|   Not sure|                null|           No|Often: 1-2 days p...|Start a free tria...|           Amused|Stack Overflow (p...|Visit Stack Overf...|    Windows|    2 to 9 employees|  Android;iOS;Kuber...|             Windows|                null|Straight / Hetero...|       No| No, not at all|                null|Multiple times pe...|Neither easy nor ...|Appropriate in le...|   No|Computer science,...|          ASP.NET Core|ASP.NET;ASP.NET Core|Just as welcome n...|       50.0|       36|          27|
# |         2|I am a developer ...|      No|null|        19|    null|     null|         null|    United Kingdom|      Pound sterling|           GBP|                  null|                null|Developer, full-s...|Bachelor’s degree...|  Employed full-time|                null|  null|                null|   Very dissatisfied|I am not interest...|          Python;Swift|    JavaScript;Swift|  React Native;Tens...|        React Native|                Github;Slack|    Confluence;Jira;G...|     null|               null|    Fairly important|                null|                null|         Once a year|   Not sure|                null|           No|                null|                null|           Amused|Stack Overflow (p...|Visit Stack Overf...|      MacOS|1,000 to 4,999 em...|  iOS;Kubernetes;Li...|                 iOS|I have little or ...|                null|      Yes|Yes, definitely|Less than once pe...|Multiple times pe...|                null|                null| null|Computer science,...|                  null|                null|Somewhat more wel...|       null|        7|           4|
# |         3|I code primarily ...|     Yes|null|        15|    null|     null|         null|Russian Federation|                null|          null|                  null|                null|                null|                null|                null|                null|  null|                null|                null|                null|  Objective-C;Pytho...|Objective-C;Pytho...|                  null|                null|                        null|                    null|     null|               null|                null|                null|                null|       Once a decade|       null|                null|           No|                null|                null|             null|Stack Overflow (p...|                null|Linux-based|                null|                  null|                null|                null|                null|      Yes|  Yes, somewhat|A few times per m...|Daily or almost d...|Neither easy nor ...|Appropriate in le...| null|                null|                  null|                null|Somewhat more wel...|       null|        4|        null|
# |         4|I am a developer ...|     Yes|25.0|        18|    null|     null|         null|           Albania|        Albanian lek|           ALL|                  null|                null|                null|Master’s degree (...|                null|White or of Europ...|   Man|Flex time or a fl...|Slightly dissatis...|I’m not actively ...|                  null|                null|                  null|                null|                        null|                    null|       No|               null|Not at all import...|Curious about oth...|                null|         Once a year|   Not sure|                 Yes|          Yes|Occasionally: 1-2...|                null|             null|Stack Overflow (p...|                null|Linux-based|  20 to 99 employees|                  null|                null|I have a great de...|Straight / Hetero...|      Yes|Yes, definitely|A few times per m...|Multiple times pe...|                null|                null|   No|Computer science,...|                  null|                null|Somewhat less wel...|       40.0|        7|           4|
# |         5|I used to be a de...|     Yes|31.0|        16|    null|     null|         null|     United States|                null|          null|      MySQL;PostgreSQL|MySQL;PostgreSQL;...|                null|Bachelor’s degree...|  Employed full-time|White or of Europ...|   Man|                null|                null|                null|       Java;Ruby;Scala|   HTML/CSS;Ruby;SQL|          Ansible;Chef|             Ansible|        Github;Google Sui...|    Confluence;Jira;G...|     null|               null|      Very important|                null|                null|         Once a year|         No|                null|          Yes|                null|Start a free tria...|Hello, old friend|Stack Overflow (p...|Call a coworker o...|    Windows|                null|  Docker;Google Clo...|AWS;Docker;Linux;...|                null|Straight / Hetero...|      Yes|  Yes, somewhat|Less than once pe...|A few times per m...|                Easy|           Too short|   No|Computer science,...|  Django;Ruby on Rails|       Ruby on Rails|Just as welcome n...|       null|       15|           8|
# |         6|I am a developer ...|      No|null|        14|    null|     null|         null|           Germany|       European Euro|           EUR|                  null|                null|Designer;Develope...|Secondary school ...|  Employed full-time|White or of Europ...|   Man|Diversity of the ...|  Slightly satisfied|I am not interest...|  HTML/CSS;Java;Jav...|HTML/CSS;Java;Jav...|                  null|                null|                Github;Slack|    Confluence;Github...| Not sure|               null|    Fairly important|                null|                null|         Once a year|         No|                  No|           No|               Never|Ask developers I ...|           Amused|Stack Overflow (p...|Play games;Visit ...|    Windows|                null|               Android|Android;Docker;Wo...|I have some influ...|Straight / Hetero...|      Yes|  Yes, somewhat|A few times per m...|A few times per week|Neither easy nor ...|Appropriate in le...| null|                null|              React.js|                null|                null|       null|        6|           4|
# |         7|I am a developer ...|     Yes|null|        18| Monthly|     null|         null|             India|United States dollar|           USD|                  null|                null|Developer, back-e...|Bachelor’s degree...|  Employed full-time|                null|  null|                null|      Very satisfied|I’m not actively ...|       C#;HTML/CSS;PHP|     C#;HTML/CSS;PHP|                  null|                null|                        null|                    null|      Yes|Extremely important|      Very important|Better compensati...|Read company medi...|    Every few months|        Yes|                 Yes|           No|Sometimes: 1-2 da...|Start a free tria...|             null|Stack Overflow (p...|                null|    Windows|  20 to 99 employees|                  null|                null|                null|                null|      Yes|Yes, definitely|Multiple times pe...|Multiple times pe...|                null|                null| null|Computer science,...|                  null|                null|A lot more welcom...|       null|        6|           4|
# |         8|I am a developer ...|     Yes|36.0|        12|  Yearly| 116000.0|     116000.0|     United States|United States dollar|           USD|               MongoDB| MariaDB;MySQL;Redis|Developer, back-e...|Bachelor’s degree...|  Employed full-time|White or of Europ...|   Man|Remote work optio...|Slightly dissatis...|I’m not actively ...|            JavaScript|          Python;SQL|              Unity 3D|             Ansible|                        null|    Confluence;Jira;G...|      Yes|Extremely important|Not at all import...|Curious about oth...|Read company medi...|         Once a year|   Not sure|                 Yes|           No|Occasionally: 1-2...|Start a free tria...|Hello, old friend|Stack Overflow (p...|Play games;Call a...|Linux-based|  20 to 99 employees|  iOS;Slack Apps an...|              Docker|I have some influ...|Straight / Hetero...|      Yes| No, not really|Less than once pe...|Multiple times pe...|                Easy|Appropriate in le...|   No|Computer science,...|  Django;React.js;V...|               Flask|Just as welcome n...|       39.0|       17|          13|
# |         9|I am a developer ...|      No|30.0|        20|    null|     null|         null|           Tunisia|United States dollar|           USD|                  null|                null|Developer, full-s...|Professional degr...|Independent contr...|                null|   Man|Diversity of the ...|   Very dissatisfied|I’m not actively ...|           Python;Rust|HTML/CSS;JavaScri...|                  null|                null|                        null|    Github;Slack;Trel...|     null|               null|      Very important|Curious about oth...|                null|         Once a year|         No|                 Yes|           No|Occasionally: 1-2...|  Start a free trial|Hello, old friend|Stack Overflow (p...|            Meditate|    Windows|Just me - I am a ...|                  null|           WordPress|                null|Straight / Hetero...|      Yes|Yes, definitely|Multiple times pe...|Multiple times pe...|Neither easy nor ...|Appropriate in le...|   No|Computer science,...|            Angular.js|              jQuery|Just as welcome n...|       50.0|        6|           4|
# |        10|I am a developer ...|     Yes|22.0|        14|  Yearly|  25000.0|      32315.0|    United Kingdom|      Pound sterling|           GBP|  Microsoft SQL Server|Microsoft SQL Server|Database administ...|Master’s degree (...|  Employed full-time|White or of Europ...|   Man|Flex time or a fl...|      Very satisfied|I’m not actively ...|  HTML/CSS;Java;Jav...|HTML/CSS;Java;Jav...|     Pandas;TensorFlow|              Pandas|        Github;Microsoft ...|    Github;Microsoft ...|       No|            Neutral|    Fairly important|Curious about oth...|Company reviews f...|    Every few months|        Yes|Onboarding? What ...|           No|Often: 1-2 days p...|Start a free tria...|Hello, old friend|Stack Overflow (p...|Visit Stack Overflow|    Windows|    2 to 9 employees|  Android;Linux;Ras...|Android;Linux;Ras...|I have a great de...|Straight / Hetero...|      Yes|Yes, definitely|Multiple times pe...|Multiple times pe...|                Easy|Appropriate in le...|   No|Mathematics or st...|          Flask;jQuery|        Flask;jQuery|Somewhat more wel...|       36.0|        8|           4|
# |        11|I am a developer ...|     Yes|23.0|        13|  Yearly|  31000.0|      40070.0|    United Kingdom|      Pound sterling|           GBP|  Firebase;MongoDB;...|Firebase;MongoDB;...|Developer, back-e...|Bachelor’s degree...|  Employed full-time|White or of Europ...|   Man|Flex time or a fl...|Slightly dissatis...|I am actively loo...|  Go;JavaScript;Swi...| C#;JavaScript;Swift|  Node.js;React Native|             Node.js|        Jira;Github;Slack...|    Confluence;Jira;G...|       No|Extremely important|      Very important|Curious about oth...|Read company medi...|    Every few months|         No|                 Yes|           No|Rarely: 1-2 days ...|                null|          Annoyed|Stack Overflow (p...|Play games;Call a...|    Windows|10,000 or more em...|  AWS;Docker;iOS;MacOS|      AWS;Heroku;iOS|I have little or ...|Straight / Hetero...|      Yes|  Yes, somewhat|I have never part...|Multiple times pe...|                Easy|Appropriate in le...|   No|Computer science,...|  Angular;Django;Re...|Angular;Angular.j...|Just as welcome n...|       40.0|       10|           2|
# |        12|I am a developer ...|      No|49.0|        42| Monthly|   1100.0|      14268.0|             Spain|       European Euro|           EUR|                  null|                null|Designer;Develope...|Some college/univ...|  Employed full-time|White or of Europ...|   Man|Remote work optio...|   Very dissatisfied|I’m not actively ...|   HTML/CSS;JavaScript| HTML/CSS;JavaScript|                  .NET|                .NET|                      Github|                  Github| Not sure|            Neutral|  Somewhat important| Better compensation|Personal network ...|Once every few years|   Not sure|                  No|           No|Rarely: 1-2 days ...|                null|      Indifferent|Stack Overflow (p...|Visit Stack Overflow|    Windows|    2 to 9 employees|     Windows;WordPress|   Windows;WordPress|I have little or ...|Straight / Hetero...|      Yes|  Yes, somewhat|A few times per week|Multiple times pe...|                Easy|Appropriate in le...|   No|Mathematics or st...|        ASP.NET;jQuery|      ASP.NET;jQuery|Just as welcome n...|       40.0|        7|           7|
# |        13|I am not primaril...|     Yes|53.0|        14| Monthly|   3000.0|      38916.0|       Netherlands|       European Euro|           EUR|                  null|                null|Designer;Develope...|Secondary school ...|  Employed full-time|White or of Europ...|   Man|Industry that I’d...|      Very satisfied|I am not interest...|                Python| C;JavaScript;Python|                  null|                null|                        null|                    null|       No|               null|Not at all import...|Having a bad day ...|Read company medi...|Once every few years|         No|                 Yes|           No|Rarely: 1-2 days ...|  Start a free trial|           Amused|Stack Overflow (p...|Call a coworker o...|      MacOS|    2 to 9 employees|   Linux;MacOS;Windows|       MacOS;Windows|I have some influ...|Straight / Hetero...|      Yes|Yes, definitely|Multiple times pe...|Multiple times pe...|Neither easy nor ...|            Too long|   No|                null|                  null|                null|A lot less welcom...|       36.0|       35|          20|
# |        14|I am a developer ...|     Yes|27.0|        13|  Yearly|  66000.0|      66000.0|     United States|United States dollar|           USD|  Firebase;Microsof...|Firebase;Microsof...|Developer, deskto...|Associate degree ...|  Employed full-time|White or of Europ...|   Man|Industry that I’d...|  Slightly satisfied|I’m not actively ...|  HTML/CSS;JavaScri...|HTML/CSS;JavaScri...|               Node.js|             Node.js|        Confluence;Jira;G...|    Confluence;Jira;G...|      Yes|Extremely important|  Somewhat important|Wanting to share ...|Read company medi...|    Every few months|         No|                 Yes|           No|Occasionally: 1-2...|                null|           Amused|Stack Overflow (p...|Call a coworker o...|    Windows|100 to 499 employees|  Google Cloud Plat...|Google Cloud Plat...|I have little or ...|Straight / Hetero...|      Yes|Yes, definitely|A few times per week|Multiple times pe...|Neither easy nor ...|Appropriate in le...|   No|Computer science,...|        Angular;Vue.js|      Angular;Vue.js|Just as welcome n...|       40.0|        5|           1|
# |        15|I am a student wh...|     Yes|null|        13|    null|     null|         null|            France|                null|          null|                  null|        MySQL;Oracle|                null|Bachelor’s degree...|             Student|                null|   Man|Languages, framew...|                null|I’m not actively ...|  Assembly;Bash/She...|Bash/Shell/PowerS...|                  null|                null|               Github;Gitlab|                  Github|     null|               null|                null|                null|                null|Once every few years|        Yes|                null|           No|                null|Ask developers I ...|          Annoyed|Stack Overflow (p...|Play games;Visit ...|Linux-based|                null|                 Linux|               Linux|                null|      Gay or Lesbian|       No| No, not really|                null|A few times per m...|                Easy|Appropriate in le...|   No|Computer science,...|                  null|                null|Just as welcome n...|       null|        4|        null|
# |        16|I am a developer ...|     Yes|45.0|         8| Monthly|   7000.0|     108576.0|    United Kingdom|      Pound sterling|           GBP|                  null|          PostgreSQL|Database administ...|Bachelor’s degree...|Independent contr...|White or of Europ...|   Man|Industry that I’d...|      Very satisfied|I’m not actively ...|                    Go|Bash/Shell/PowerS...|                  null|                null|                        null|    Github;Slack;Goog...|       No|Extremely important|    Fairly important|Having a bad day ...|Personal network ...|         Once a year|   Not sure|                 Yes|           No|Often: 1-2 days p...|Ask developers I ...|Hello, old friend|Stack Overflow (p...|Visit Stack Overf...|      MacOS|Just me - I am a ...|                  null|AWS;Docker;Google...|                null|Straight / Hetero...|      Yes|  Yes, somewhat|Multiple times pe...|Multiple times pe...|                Easy|Appropriate in le...|   No|Computer science,...|                  null|     jQuery;React.js|Just as welcome n...|       50.0|       37|          23|
# |        17|I am a developer ...|     Yes|25.0|        14|  Yearly|  79000.0|      79000.0|     United States|United States dollar|           USD|  Cassandra;Elastic...|Microsoft SQL Ser...|Developer, full-s...|Bachelor’s degree...|  Employed full-time|White or of Europ...|   Man|Industry that I’d...|Slightly dissatis...|I’m not actively ...|  C#;Go;Haskell;HTM...|C#;HTML/CSS;JavaS...|    .NET Core;Teraform|        .NET;Node.js|        Github;Gitlab;Sla...|    Github;Gitlab;Sla...|      Yes|Extremely important|    Fairly important|Having a bad day ...|Company reviews f...|         Once a year|   Not sure|                  No|           No|Rarely: 1-2 days ...|                null|Hello, old friend|Stack Overflow (p...|Call a coworker o...|    Windows|  20 to 99 employees|  Docker;Kubernetes...|                null|I have little or ...|Straight / Hetero...|      Yes| No, not at all|I have never part...|Daily or almost d...|                Easy|Appropriate in le...|   No|Computer science,...|  ASP.NET Core;Gats...|ASP.NET;Gatsby;jQ...|Just as welcome n...|       40.0|        7|           3|
# |        18|I am a developer ...|     Yes|32.0|        12| Monthly| 105000.0|    1260000.0|     United States|United States dollar|           USD|  Elasticsearch;Pos...|Elasticsearch;Mar...| Developer, back-end|Bachelor’s degree...|  Employed full-time|White or of Europ...|   Man|Languages, framew...|      Very satisfied|I am not interest...|         HTML/CSS;Perl|Bash/Shell/PowerS...|                  null|                null|                      Github|            Github;Slack| Not sure|            Neutral|      Very important| Looking to relocate|                null|Once every few years|        Yes|Onboarding? What ...|          Yes|Occasionally: 1-2...|Start a free tria...|Hello, old friend|Stack Overflow (p...|Play games;Visit ...|Linux-based|100 to 499 employees|                 Linux|           AWS;Linux|I have some influ...|Straight / Hetero...|      Yes|  Yes, somewhat|I have never part...|Daily or almost d...|Neither easy nor ...|Appropriate in le...|   No|Computer science,...|                  null|                null|Just as welcome n...|       45.0|       19|          12|
# |        19|I am a developer ...|      No|24.0|        15|  Yearly|  83400.0|      83400.0|     United States|United States dollar|           USD|       MariaDB;MongoDB|MariaDB;Microsoft...|Developer, full-s...|Bachelor’s degree...|  Employed full-time|White or of Europ...|   Man|Flex time or a fl...|Slightly dissatis...|I’m not actively ...|  C#;Go;Python;Type...|Bash/Shell/PowerS...|  Node.js;React Nat...|.NET;.NET Core;No...|                Github;Slack|    Confluence;Jira;G...|      Yes|Extremely important|    Fairly important|Having a bad day ...|Company reviews f...|         Once a year|        Yes|                  No|           No|Occasionally: 1-2...|                null|Hello, old friend|Stack Overflow (p...|Call a coworker o...|    Windows|10,000 or more em...|  iOS;Slack Apps an...|             Windows|I have little or ...|Straight / Hetero...|      Yes|        Neutral|Less than once pe...|A few times per week|                Easy|Appropriate in le...|   No|Computer science,...|  Django;Express;Re...|Angular;Angular.j...|Just as welcome n...|       35.0|        9|           3|
# |        20|I am a developer ...|     Yes|40.0|        18|    null|     null|         null|             Spain|       European Euro|           EUR|                  null|IBM DB2;MariaDB;M...|Developer, deskto...|Bachelor’s degree...|  Employed full-time|Hispanic or Latin...|   Man|                null|Neither satisfied...|I’m not actively ...|                    Go| Java;JavaScript;SQL|            TensorFlow|             Node.js|                      Github|             Jira;Github|      Yes|            Neutral|      Very important|Having a bad day ...|Personal network ...|Once every few years|   Not sure|                  No|           No|Often: 1-2 days p...|                null|Hello, old friend|Stack Overflow (p...|Meditate;Call a c...|    Windows|100 to 499 employees|                  null|Heroku;Linux;Windows|I have little or ...|Straight / Hetero...|      Yes|  Yes, somewhat|A few times per m...|Multiple times pe...|                Easy|           Too short|   No|Another engineeri...|                Spring|   Angular.js;Spring|Just as welcome n...|       50.0|       22|          17|
# +----------+--------------------+--------+----+----------+--------+---------+-------------+------------------+--------------------+--------------+----------------------+--------------------+--------------------+--------------------+--------------------+--------------------+------+--------------------+--------------------+--------------------+----------------------+--------------------+----------------------+--------------------+----------------------------+------------------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+-----------+--------------------+-------------+--------------------+--------------------+-----------------+--------------------+--------------------+-----------+--------------------+----------------------+--------------------+--------------------+--------------------+---------+---------------+--------------------+--------------------+--------------------+--------------------+-----+--------------------+----------------------+--------------------+--------------------+-----------+---------+------------+
# only showing top 20 rows

# %%
df.show(10, truncate=False) # pokaż 10 wierszy, nie skracaj danych
# Out:
# +----------+--------------------------------------------------------+--------+----+----------+--------+---------+-------------+------------------+--------------------+--------------+----------------------+-----------------------------------------+---------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------+----------------------------------------------------+----------------------------+------+------------------------------------------------------------------------------------------------------------------------------------------------+---------------------+------------------------------------------------------------+-------------------------------------+-----------------------------------+--------------------------------+------------------+--------------------------------------+---------------------------------------------------------------------------+---------+-------------------+----------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------+-----------+----------------------------+-------------+--------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------+--------------------------------------------------+-------------------------------------------------+----------------------------------+--------------------------------+-----------------------+---------+---------------+-----------------------------------+-------------------------------+--------------------------+---------------------+-----+---------------------------------------------------------------+----------------------+--------------------+----------------------------------------+-----------+---------+------------+
# |Respondent|MainBranch                                              |Hobbyist|Age |Age1stCode|CompFreq|CompTotal|ConvertedComp|Country           |CurrencyDesc        |CurrencySymbol|DatabaseDesireNextYear|DatabaseWorkedWith                       |DevType                                                                                      |EdLevel                                                                           |Employment                                          |Ethnicity                   |Gender|JobFactors                                                                                                                                      |JobSat               |JobSeek                                                     |LanguageDesireNextYear               |LanguageWorkedWith                 |MiscTechDesireNextYear          |MiscTechWorkedWith|NEWCollabToolsDesireNextYear          |NEWCollabToolsWorkedWith                                                   |NEWDevOps|NEWDevOpsImpt      |NEWEdImpt                         |NEWJobHunt                                                                                                                                                                                                                  |NEWJobHuntResearch                                                                                                                                                                                                                                    |NEWLearn        |NEWOffTopic|NEWOnboardGood              |NEWOtherComms|NEWOvertime                                             |NEWPurchaseResearch                                                                                                                                                                                                  |NEWPurpleLink    |NEWSOSites                                                                                                                                                                                                                                                 |NEWStuck                                                                                                                                                         |OpSys      |OrgSize                                           |PlatformDesireNextYear                           |PlatformWorkedWith                |PurchaseWhat                    |Sexuality              |SOAccount|SOComm         |SOPartFreq                         |SOVisitFreq                    |SurveyEase                |SurveyLength         |Trans|UndergradMajor                                                 |WebframeDesireNextYear|WebframeWorkedWith  |WelcomeChange                           |WorkWeekHrs|YearsCode|YearsCodePro|
# +----------+--------------------------------------------------------+--------+----+----------+--------+---------+-------------+------------------+--------------------+--------------+----------------------+-----------------------------------------+---------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------+----------------------------------------------------+----------------------------+------+------------------------------------------------------------------------------------------------------------------------------------------------+---------------------+------------------------------------------------------------+-------------------------------------+-----------------------------------+--------------------------------+------------------+--------------------------------------+---------------------------------------------------------------------------+---------+-------------------+----------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------+-----------+----------------------------+-------------+--------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------+--------------------------------------------------+-------------------------------------------------+----------------------------------+--------------------------------+-----------------------+---------+---------------+-----------------------------------+-------------------------------+--------------------------+---------------------+-----+---------------------------------------------------------------+----------------------+--------------------+----------------------------------------+-----------+---------+------------+
# |1         |I am a developer by profession                          |Yes     |null|13        |Monthly |null     |null         |Germany           |European Euro       |EUR           |Microsoft SQL Server  |Elasticsearch;Microsoft SQL Server;Oracle|Developer, desktop or enterprise applications;Developer, full-stack                          |Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                   |Independent contractor, freelancer, or self-employed|White or of European descent|Man   |Languages, frameworks, and other technologies I’d be working with;Remote work options;Opportunities for professional development                |Slightly satisfied   |I am not interested in new job opportunities                |C#;HTML/CSS;JavaScript               |C#;HTML/CSS;JavaScript             |.NET Core;Xamarin               |.NET;.NET Core    |Microsoft Teams;Microsoft Azure;Trello|Confluence;Jira;Slack;Microsoft Azure;Trello                               |No       |Somewhat important |Fairly important                  |null                                                                                                                                                                                                                        |null                                                                                                                                                                                                                                                  |Once a year     |Not sure   |null                        |No           |Often: 1-2 days per week or more                        |Start a free trial;Ask developers I know/work with                                                                                                                                                                   |Amused           |Stack Overflow (public Q&A for anyone who codes)                                                                                                                                                                                                           |Visit Stack Overflow;Go for a walk or other physical activity;Do other work and come back later                                                                  |Windows    |2 to 9 employees                                  |Android;iOS;Kubernetes;Microsoft Azure;Windows   |Windows                           |null                            |Straight / Heterosexual|No       |No, not at all |null                               |Multiple times per day         |Neither easy nor difficult|Appropriate in length|No   |Computer science, computer engineering, or software engineering|ASP.NET Core          |ASP.NET;ASP.NET Core|Just as welcome now as I felt last year |50.0       |36       |27          |
# |2         |I am a developer by profession                          |No      |null|19        |null    |null     |null         |United Kingdom    |Pound sterling      |GBP           |null                  |null                                     |Developer, full-stack;Developer, mobile                                                      |Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                      |Employed full-time                                  |null                        |null  |null                                                                                                                                            |Very dissatisfied    |I am not interested in new job opportunities                |Python;Swift                         |JavaScript;Swift                   |React Native;TensorFlow;Unity 3D|React Native      |Github;Slack                          |Confluence;Jira;Github;Gitlab;Slack                                        |null     |null               |Fairly important                  |null                                                                                                                                                                                                                        |null                                                                                                                                                                                                                                                  |Once a year     |Not sure   |null                        |No           |null                                                    |null                                                                                                                                                                                                                 |Amused           |Stack Overflow (public Q&A for anyone who codes);Stack Exchange (public Q&A for a variety of topics);Stack Overflow Jobs (for job seekers)                                                                                                                 |Visit Stack Overflow;Go for a walk or other physical activity                                                                                                    |MacOS      |1,000 to 4,999 employees                          |iOS;Kubernetes;Linux;MacOS                       |iOS                               |I have little or no influence   |null                   |Yes      |Yes, definitely|Less than once per month or monthly|Multiple times per day         |null                      |null                 |null |Computer science, computer engineering, or software engineering|null                  |null                |Somewhat more welcome now than last year|null       |7        |4           |
# |3         |I code primarily as a hobby                             |Yes     |null|15        |null    |null     |null         |Russian Federation|null                |null          |null                  |null                                     |null                                                                                         |null                                                                              |null                                                |null                        |null  |null                                                                                                                                            |null                 |null                                                        |Objective-C;Python;Swift             |Objective-C;Python;Swift           |null                            |null              |null                                  |null                                                                       |null     |null               |null                              |null                                                                                                                                                                                                                        |null                                                                                                                                                                                                                                                  |Once a decade   |null       |null                        |No           |null                                                    |null                                                                                                                                                                                                                 |null             |Stack Overflow (public Q&A for anyone who codes)                                                                                                                                                                                                           |null                                                                                                                                                             |Linux-based|null                                              |null                                             |null                              |null                            |null                   |Yes      |Yes, somewhat  |A few times per month or weekly    |Daily or almost daily          |Neither easy nor difficult|Appropriate in length|null |null                                                           |null                  |null                |Somewhat more welcome now than last year|null       |4        |null        |
# |4         |I am a developer by profession                          |Yes     |25.0|18        |null    |null     |null         |Albania           |Albanian lek        |ALL           |null                  |null                                     |null                                                                                         |Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                   |null                                                |White or of European descent|Man   |Flex time or a flexible schedule;Office environment or company culture;Opportunities for professional development                               |Slightly dissatisfied|I’m not actively looking, but I am open to new opportunities|null                                 |null                               |null                            |null              |null                                  |null                                                                       |No       |null               |Not at all important/not necessary|Curious about other opportunities;Wanting to work with new technologies                                                                                                                                                     |null                                                                                                                                                                                                                                                  |Once a year     |Not sure   |Yes                         |Yes          |Occasionally: 1-2 days per quarter but less than monthly|null                                                                                                                                                                                                                 |null             |Stack Overflow (public Q&A for anyone who codes);Stack Exchange (public Q&A for a variety of topics);Stack Overflow Jobs (for job seekers)                                                                                                                 |null                                                                                                                                                             |Linux-based|20 to 99 employees                                |null                                             |null                              |I have a great deal of influence|Straight / Heterosexual|Yes      |Yes, definitely|A few times per month or weekly    |Multiple times per day         |null                      |null                 |No   |Computer science, computer engineering, or software engineering|null                  |null                |Somewhat less welcome now than last year|40.0       |7        |4           |
# |5         |I used to be a developer by profession, but no longer am|Yes     |31.0|16        |null    |null     |null         |United States     |null                |null          |MySQL;PostgreSQL      |MySQL;PostgreSQL;Redis;SQLite            |null                                                                                         |Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                      |Employed full-time                                  |White or of European descent|Man   |null                                                                                                                                            |null                 |null                                                        |Java;Ruby;Scala                      |HTML/CSS;Ruby;SQL                  |Ansible;Chef                    |Ansible           |Github;Google Suite (Docs, Meet, etc) |Confluence;Jira;Github;Slack;Google Suite (Docs, Meet, etc)                |null     |null               |Very important                    |null                                                                                                                                                                                                                        |null                                                                                                                                                                                                                                                  |Once a year     |No         |null                        |Yes          |null                                                    |Start a free trial;Ask developers I know/work with;Visit developer communities like Stack Overflow;Read ratings or reviews on third party sites like G2Crowd;Research companies that have advertised on sites I visit|Hello, old friend|Stack Overflow (public Q&A for anyone who codes);Stack Exchange (public Q&A for a variety of topics);Stack Overflow Jobs (for job seekers);Stack Overflow for Teams (private Q&A for organizations);Stack Overflow Talent (for hiring companies/recruiters)|Call a coworker or friend;Visit Stack Overflow;Watch help / tutorial videos;Do other work and come back later;Visit another developer community (please name):   |Windows    |null                                              |Docker;Google Cloud Platform;Heroku;Linux;Windows|AWS;Docker;Linux;MacOS;Windows    |null                            |Straight / Heterosexual|Yes      |Yes, somewhat  |Less than once per month or monthly|A few times per month or weekly|Easy                      |Too short            |No   |Computer science, computer engineering, or software engineering|Django;Ruby on Rails  |Ruby on Rails       |Just as welcome now as I felt last year |null       |15       |8           |
# |6         |I am a developer by profession                          |No      |null|14        |null    |null     |null         |Germany           |European Euro       |EUR           |null                  |null                                     |Designer;Developer, front-end;Developer, mobile                                              |Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)|Employed full-time                                  |White or of European descent|Man   |Diversity of the company or organization;Languages, frameworks, and other technologies I’d be working with;Office environment or company culture|Slightly satisfied   |I am not interested in new job opportunities                |HTML/CSS;Java;JavaScript             |HTML/CSS;Java;JavaScript           |null                            |null              |Github;Slack                          |Confluence;Github;Slack;Trello                                             |Not sure |null               |Fairly important                  |null                                                                                                                                                                                                                        |null                                                                                                                                                                                                                                                  |Once a year     |No         |No                          |No           |Never                                                   |Ask developers I know/work with;Read ratings or reviews on third party sites like G2Crowd                                                                                                                            |Amused           |Stack Overflow (public Q&A for anyone who codes);Stack Exchange (public Q&A for a variety of topics)                                                                                                                                                       |Play games;Visit Stack Overflow;Watch help / tutorial videos;Do other work and come back later                                                                   |Windows    |null                                              |Android                                          |Android;Docker;WordPress          |I have some influence           |Straight / Heterosexual|Yes      |Yes, somewhat  |A few times per month or weekly    |A few times per week           |Neither easy nor difficult|Appropriate in length|null |null                                                           |React.js              |null                |null                                    |null       |6        |4           |
# |7         |I am a developer by profession                          |Yes     |null|18        |Monthly |null     |null         |India             |United States dollar|USD           |null                  |null                                     |Developer, back-end;Developer, front-end;Developer, QA or test;DevOps specialist             |Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                      |Employed full-time                                  |null                        |null  |null                                                                                                                                            |Very satisfied       |I’m not actively looking, but I am open to new opportunities|C#;HTML/CSS;PHP                      |C#;HTML/CSS;PHP                    |null                            |null              |null                                  |null                                                                       |Yes      |Extremely important|Very important                    |Better compensation;Growth or leadership opportunities                                                                                                                                                                      |Read company media, such as employee blogs or company culture videos;Company reviews from third party sites (e.g. Glassdoor, Blind);Publicly available financial information (e.g. Crunchbase);Personal network - friends or family                   |Every few months|Yes        |Yes                         |No           |Sometimes: 1-2 days per month but less than weekly      |Start a free trial;Ask developers I know/work with                                                                                                                                                                   |null             |Stack Overflow (public Q&A for anyone who codes)                                                                                                                                                                                                           |null                                                                                                                                                             |Windows    |20 to 99 employees                                |null                                             |null                              |null                            |null                   |Yes      |Yes, definitely|Multiple times per day             |Multiple times per day         |null                      |null                 |null |Computer science, computer engineering, or software engineering|null                  |null                |A lot more welcome now than last year   |null       |6        |4           |
# |8         |I am a developer by profession                          |Yes     |36.0|12        |Yearly  |116000.0 |116000.0     |United States     |United States dollar|USD           |MongoDB               |MariaDB;MySQL;Redis                      |Developer, back-end;Developer, desktop or enterprise applications;Developer, game or graphics|Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                      |Employed full-time                                  |White or of European descent|Man   |Remote work options;Opportunities for professional development;Family friendliness                                                              |Slightly dissatisfied|I’m not actively looking, but I am open to new opportunities|JavaScript                           |Python;SQL                         |Unity 3D                        |Ansible           |null                                  |Confluence;Jira;Github;Slack;Microsoft Teams;Google Suite (Docs, Meet, etc)|Yes      |Extremely important|Not at all important/not necessary|Curious about other opportunities;Better compensation;Trouble with my direct manager;Trouble with leadership at my company;Better work/life balance;Wanting to work with new technologies;Growth or leadership opportunities|Read company media, such as employee blogs or company culture videos;Company reviews from third party sites (e.g. Glassdoor, Blind);Personal network - friends or family;Read other media like news articles, founder profiles, etc. about the company|Once a year     |Not sure   |Yes                         |No           |Occasionally: 1-2 days per quarter but less than monthly|Start a free trial;Ask developers I know/work with;Visit developer communities like Stack Overflow;Read ratings or reviews on third party sites like G2Crowd                                                         |Hello, old friend|Stack Overflow (public Q&A for anyone who codes);Stack Overflow Jobs (for job seekers)                                                                                                                                                                     |Play games;Call a coworker or friend;Visit Stack Overflow;Go for a walk or other physical activity;Watch help / tutorial videos;Do other work and come back later|Linux-based|20 to 99 employees                                |iOS;Slack Apps and Integrations                  |Docker                            |I have some influence           |Straight / Heterosexual|Yes      |No, not really |Less than once per month or monthly|Multiple times per day         |Easy                      |Appropriate in length|No   |Computer science, computer engineering, or software engineering|Django;React.js;Vue.js|Flask               |Just as welcome now as I felt last year |39.0       |17       |13          |
# |9         |I am a developer by profession                          |No      |30.0|20        |null    |null     |null         |Tunisia           |United States dollar|USD           |null                  |null                                     |Developer, full-stack                                                                        |Professional degree (JD, MD, etc.)                                                |Independent contractor, freelancer, or self-employed|null                        |Man   |Diversity of the company or organization;Remote work options;Office environment or company culture                                              |Very dissatisfied    |I’m not actively looking, but I am open to new opportunities|Python;Rust                          |HTML/CSS;JavaScript;PHP            |null                            |null              |null                                  |Github;Slack;Trello;Google Suite (Docs, Meet, etc)                         |null     |null               |Very important                    |Curious about other opportunities;Growth or leadership opportunities                                                                                                                                                        |null                                                                                                                                                                                                                                                  |Once a year     |No         |Yes                         |No           |Occasionally: 1-2 days per quarter but less than monthly|Start a free trial                                                                                                                                                                                                   |Hello, old friend|Stack Overflow (public Q&A for anyone who codes);Stack Exchange (public Q&A for a variety of topics)                                                                                                                                                       |Meditate                                                                                                                                                         |Windows    |Just me - I am a freelancer, sole proprietor, etc.|null                                             |WordPress                         |null                            |Straight / Heterosexual|Yes      |Yes, definitely|Multiple times per day             |Multiple times per day         |Neither easy nor difficult|Appropriate in length|No   |Computer science, computer engineering, or software engineering|Angular.js            |jQuery              |Just as welcome now as I felt last year |50.0       |6        |4           |
# |10        |I am a developer by profession                          |Yes     |22.0|14        |Yearly  |25000.0  |32315.0      |United Kingdom    |Pound sterling      |GBP           |Microsoft SQL Server  |Microsoft SQL Server                     |Database administrator;Developer, full-stack;Developer, mobile                               |Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                   |Employed full-time                                  |White or of European descent|Man   |Flex time or a flexible schedule;How widely used or impactful my work output would be;Opportunities for professional development                |Very satisfied       |I’m not actively looking, but I am open to new opportunities|HTML/CSS;Java;JavaScript;Python;R;SQL|HTML/CSS;Java;JavaScript;Python;SQL|Pandas;TensorFlow               |Pandas            |Github;Microsoft Teams                |Github;Microsoft Teams                                                     |No       |Neutral            |Fairly important                  |Curious about other opportunities;Better compensation;Looking to relocate                                                                                                                                                   |Company reviews from third party sites (e.g. Glassdoor, Blind);Publicly available financial information (e.g. Crunchbase);Personal network - friends or family;Read other media like news articles, founder profiles, etc. about the company          |Every few months|Yes        |Onboarding? What onboarding?|No           |Often: 1-2 days per week or more                        |Start a free trial;Ask developers I know/work with;Visit developer communities like Stack Overflow                                                                                                                   |Hello, old friend|Stack Overflow (public Q&A for anyone who codes);Stack Exchange (public Q&A for a variety of topics)                                                                                                                                                       |Visit Stack Overflow                                                                                                                                             |Windows    |2 to 9 employees                                  |Android;Linux;Raspberry Pi;Windows               |Android;Linux;Raspberry Pi;Windows|I have a great deal of influence|Straight / Heterosexual|Yes      |Yes, definitely|Multiple times per day             |Multiple times per day         |Easy                      |Appropriate in length|No   |Mathematics or statistics                                      |Flask;jQuery          |Flask;jQuery        |Somewhat more welcome now than last year|36.0       |8        |4           |
# +----------+--------------------------------------------------------+--------+----+----------+--------+---------+-------------+------------------+--------------------+--------------+----------------------+-----------------------------------------+---------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------+----------------------------------------------------+----------------------------+------+------------------------------------------------------------------------------------------------------------------------------------------------+---------------------+------------------------------------------------------------+-------------------------------------+-----------------------------------+--------------------------------+------------------+--------------------------------------+---------------------------------------------------------------------------+---------+-------------------+----------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------+-----------+----------------------------+-------------+--------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------+--------------------------------------------------+-------------------------------------------------+----------------------------------+--------------------------------+-----------------------+---------+---------------+-----------------------------------+-------------------------------+--------------------------+---------------------+-----+---------------------------------------------------------------+----------------------+--------------------+----------------------------------------+-----------+---------+------------+
# only showing top 10 rows

# %%
df.select("Age").show()  # pokaż tylko jedną kolumne
# Out:
# +----+
# | Age|
# +----+
# |null|
# |null|
# |null|
# |25.0|
# |31.0|
# |null|
# |null|
# |36.0|
# |30.0|
# |22.0|
# |23.0|
# |49.0|
# |53.0|
# |27.0|
# |null|
# |45.0|
# |25.0|
# |32.0|
# |24.0|
# |40.0|
# +----+
# only showing top 20 rows

# %%
df.select("Country", "Age", "ConvertedComp").show() # pokaż wybrane kolumny
# Out:
# +------------------+----+-------------+
# |           Country| Age|ConvertedComp|
# +------------------+----+-------------+
# |           Germany|null|         null|
# |    United Kingdom|null|         null|
# |Russian Federation|null|         null|
# |           Albania|25.0|         null|
# |     United States|31.0|         null|
# |           Germany|null|         null|
# |             India|null|         null|
# |     United States|36.0|     116000.0|
# |           Tunisia|30.0|         null|
# |    United Kingdom|22.0|      32315.0|
# |    United Kingdom|23.0|      40070.0|
# |             Spain|49.0|      14268.0|
# |       Netherlands|53.0|      38916.0|
# |     United States|27.0|      66000.0|
# |            France|null|         null|
# |    United Kingdom|45.0|     108576.0|
# |     United States|25.0|      79000.0|
# |     United States|32.0|    1260000.0|
# |     United States|24.0|      83400.0|
# |             Spain|40.0|         null|
# +------------------+----+-------------+
# only showing top 20 rows

# %%
df_country = df.select(df.Country).distinct() # stworz nowy DF zawierajacy tylko unikalne wartosci nazw krajow

# %%
df_country.count()
# Out:
# 184

# %%
df.filter("Country = 'Spain'")
# Out:
# DataFrame[Respondent: int, MainBranch: string, Hobbyist: string, Age: double, Age1stCode: string, CompFreq: string, CompTotal: double, ConvertedComp: double, Country: string, CurrencyDesc: string, CurrencySymbol: string, DatabaseDesireNextYear: string, DatabaseWorkedWith: string, DevType: string, EdLevel: string, Employment: string, Ethnicity: string, Gender: string, JobFactors: string, JobSat: string, JobSeek: string, LanguageDesireNextYear: string, LanguageWorkedWith: string, MiscTechDesireNextYear: string, MiscTechWorkedWith: string, NEWCollabToolsDesireNextYear: string, NEWCollabToolsWorkedWith: string, NEWDevOps: string, NEWDevOpsImpt: string, NEWEdImpt: string, NEWJobHunt: string, NEWJobHuntResearch: string, NEWLearn: string, NEWOffTopic: string, NEWOnboardGood: string, NEWOtherComms: string, NEWOvertime: string, NEWPurchaseResearch: string, NEWPurpleLink: string, NEWSOSites: string, NEWStuck: string, OpSys: string, OrgSize: string, PlatformDesireNextYear: string, PlatformWorkedWith: string, PurchaseWhat: string, Sexuality: string, SOAccount: string, SOComm: string, SOPartFreq: string, SOVisitFreq: string, SurveyEase: string, SurveyLength: string, Trans: string, UndergradMajor: string, WebframeDesireNextYear: string, WebframeWorkedWith: string, WelcomeChange: string, WorkWeekHrs: double, YearsCode: string, YearsCodePro: string]

# %%
df.filter("Country = 'Spain' and Age > 50" ).toPandas()
# Out:
#     Respondent                                         MainBranch Hobbyist  \
# 0         2914                     I am a developer by profession       No
# 1         4466                     I am a developer by profession      Yes
# 2         8472                     I am a developer by profession       No
# 3        11567                     I am a developer by profession      Yes
# 4        12035                     I am a developer by profession       No
# 5        13809                     I am a developer by profession      Yes
# 6        17683                        I code primarily as a hobby      Yes
# 7        21897  I am not primarily a developer, but I write co...      Yes
# 8        25263                     I am a developer by profession      Yes
# 9        25791  I am not primarily a developer, but I write co...       No
# 10       26847                     I am a developer by profession      Yes
# 11       27240                     I am a developer by profession      Yes
# 12       28709                        I code primarily as a hobby      Yes
# 13       29974                     I am a developer by profession      Yes
# 14       34392                     I am a developer by profession       No
# 15       38994                     I am a developer by profession       No
# 16       40684                        I code primarily as a hobby      Yes
# 17       45629  I am not primarily a developer, but I write co...      Yes
# 18       47053                     I am a developer by profession       No
# 19       48178                     I am a developer by profession      Yes
# 20       49461  I am not primarily a developer, but I write co...      Yes
# 21       50700                     I am a developer by profession       No
# 22       51995  I am not primarily a developer, but I write co...      Yes
# 23       52868                     I am a developer by profession      Yes
# 24       56420  I am not primarily a developer, but I write co...       No
# 25       57124                     I am a developer by profession      Yes
# 26       57795                     I am a developer by profession       No
#
#      Age Age1stCode CompFreq  CompTotal  ConvertedComp Country   CurrencyDesc  \
# 0   57.0         17   Yearly    57000.0        61616.0   Spain  European Euro
# 1   59.0         15     None        NaN            NaN   Spain  European Euro
# 2   53.0         16   Yearly    50000.0        54049.0   Spain  European Euro
# 3   55.0         12   Yearly    80000.0        86478.0   Spain  European Euro
# 4   52.0         19   Yearly    15000.0        16215.0   Spain  European Euro
# 5   52.0         11  Monthly     5000.0        64860.0   Spain  European Euro
# 6   54.0         17     None        NaN            NaN   Spain           None
# 7   51.0         13  Monthly        NaN            NaN   Spain  European Euro
# 8   51.0         19   Yearly    70000.0        75669.0   Spain  European Euro
# 9   54.0         24   Yearly    52000.0        56211.0   Spain  European Euro
# 10  55.0         20     None        NaN            NaN   Spain  European Euro
# 11  53.0         14  Monthly    75000.0       972888.0   Spain  European Euro
# 12  53.0         14     None        NaN            NaN   Spain           None
# 13  55.0         12   Yearly    28000.0        30267.0   Spain  European Euro
# 14  66.0         19   Yearly    55000.0        59454.0   Spain  European Euro
# 15  53.0         15  Monthly    30000.0       389148.0   Spain  European Euro
# 16  57.0         47     None        NaN            NaN   Spain           None
# 17  53.0         11     None        NaN            NaN   Spain  European Euro
# 18  55.0         15     None        NaN            NaN   Spain  European Euro
# 19  59.0         15     None        NaN            NaN   Spain           None
# 20  57.0         13   Yearly    70000.0        75669.0   Spain  European Euro
# 21  52.0         16  Monthly    45000.0       583728.0   Spain  European Euro
# 22  54.0         22   Yearly    43000.0        46482.0   Spain  European Euro
# 23  51.0         20   Yearly    40000.0        43239.0   Spain  European Euro
# 24  54.0         45   Yearly    60000.0        64859.0   Spain  European Euro
# 25  54.0         18  Monthly     2000.0        25944.0   Spain  European Euro
# 26  56.0         14   Yearly    25000.0        27025.0   Spain  European Euro
#
#    CurrencySymbol                             DatabaseDesireNextYear  \
# 0             EUR                                            MongoDB
# 1             EUR                           MongoDB;MySQL;PostgreSQL
# 2             EUR                    Microsoft SQL Server;PostgreSQL
# 3             EUR                                               None
# 4             EUR          MariaDB;Microsoft SQL Server;MySQL;SQLite
# 5             EUR                                               None
# 6            None  DynamoDB;Firebase;MongoDB;MySQL;PostgreSQL;SQLite
# 7             EUR                                      MongoDB;MySQL
# 8             EUR                              MariaDB;MongoDB;Redis
# 9             EUR                           MongoDB;MySQL;PostgreSQL
# 10            EUR                                      MongoDB;MySQL
# 11            EUR                                 Cassandra;DynamoDB
# 12           None                                               None
# 13            EUR                                              MySQL
# 14            EUR                                            MongoDB
# 15            EUR                                  Oracle;PostgreSQL
# 16           None                                              MySQL
# 17            EUR                                         PostgreSQL
# 18            EUR                                             SQLite
# 19           None  Cassandra;Elasticsearch;Firebase;MariaDB;Micro...
# 20            EUR                                               None
# 21            EUR                              MongoDB;Oracle;SQLite
# 22            EUR                                             SQLite
# 23            EUR                         Microsoft SQL Server;MySQL
# 24            EUR               MariaDB;Microsoft SQL Server;MongoDB
# 25            EUR                         Microsoft SQL Server;MySQL
# 26            EUR                                           Firebase
#
#                                    DatabaseWorkedWith  \
# 0                                Microsoft SQL Server
# 1       Microsoft SQL Server;MongoDB;MySQL;PostgreSQL
# 2           Elasticsearch;Microsoft SQL Server;SQLite
# 3                                              SQLite
# 4           MariaDB;Microsoft SQL Server;MySQL;SQLite
# 5                                                None
# 6                     MongoDB;MySQL;PostgreSQL;SQLite
# 7                                               MySQL
# 8                                       MariaDB;MySQL
# 9                            MongoDB;MySQL;PostgreSQL
# 10                                      MongoDB;MySQL
# 11                           Elasticsearch;PostgreSQL
# 12                                               None
# 13                                              MySQL
# 14                                       MySQL;SQLite
# 15                               IBM DB2;MySQL;Oracle
# 16                                              MySQL
# 17                                         PostgreSQL
# 18                                             SQLite
# 19                        Microsoft SQL Server;SQLite
# 20                                               None
# 21                        MariaDB;MySQL;Oracle;SQLite
# 22                                             SQLite
# 23                               Microsoft SQL Server
# 24               MariaDB;Microsoft SQL Server;MongoDB
# 25                         Microsoft SQL Server;MySQL
# 26  Firebase;MariaDB;Microsoft SQL Server;MongoDB;...
#
#                                               DevType  \
# 0   Developer, back-end;Developer, desktop or ente...
# 1   Data scientist or machine learning specialist;...
# 2   Developer, desktop or enterprise applications;...
# 3   Developer, embedded applications or devices;De...
# 4   Database administrator;Designer;Developer, bac...
# 5   Developer, back-end;Developer, desktop or ente...
# 6                                                None
# 7   Academic researcher;Data or business analyst;E...
# 8                                 Developer, back-end
# 9   Academic researcher;Developer, full-stack;Educ...
# 10  Database administrator;Developer, back-end;Dev...
# 11                                Developer, back-end
# 12           Developer, full-stack;Educator;Scientist
# 13  Developer, full-stack;Developer, QA or test;Ed...
# 14                              Developer, full-stack
# 15                                Developer, back-end
# 16                                               None
# 17                                               None
# 18  Data or business analyst;Database administrato...
# 19  Database administrator;Designer;Developer, des...
# 20  Academic researcher;Data scientist or machine ...
# 21  Database administrator;Developer, back-end;Dev...
# 22                                Developer, back-end
# 23  Database administrator;Designer;Developer, des...
# 24  Academic researcher;Data or business analyst;E...
# 25  Database administrator;Designer;Developer, ful...
# 26  Developer, full-stack;Developer, mobile;Produc...
#
#                                               EdLevel  \
# 0   Secondary school (e.g. American high school, G...
# 1     Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 2        Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3   Some college/university study without earning ...
# 4        Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 5        Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 6   Some college/university study without earning ...
# 7          Other doctoral degree (Ph.D., Ed.D., etc.)
# 8          Other doctoral degree (Ph.D., Ed.D., etc.)
# 9          Other doctoral degree (Ph.D., Ed.D., etc.)
# 10  Some college/university study without earning ...
# 11       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 12                 Professional degree (JD, MD, etc.)
# 13    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 14    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 15       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 16       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 17    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 18       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 19  Some college/university study without earning ...
# 20    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 21    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 22       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 23  Some college/university study without earning ...
# 24         Other doctoral degree (Ph.D., Ed.D., etc.)
# 25  Some college/university study without earning ...
# 26       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                            Employment  \
# 0                                  Employed full-time
# 1                                  Employed full-time
# 2   Independent contractor, freelancer, or self-em...
# 3   Independent contractor, freelancer, or self-em...
# 4   Independent contractor, freelancer, or self-em...
# 5   Independent contractor, freelancer, or self-em...
# 6                                             Retired
# 7                                  Employed full-time
# 8                                  Employed full-time
# 9                                  Employed full-time
# 10                                 Employed full-time
# 11                                 Employed full-time
# 12                                 Employed full-time
# 13                                 Employed full-time
# 14                                 Employed full-time
# 15                                 Employed full-time
# 16             Not employed, and not looking for work
# 17  Independent contractor, freelancer, or self-em...
# 18  Independent contractor, freelancer, or self-em...
# 19                 Not employed, but looking for work
# 20                                 Employed full-time
# 21                                 Employed full-time
# 22                                 Employed full-time
# 23                                 Employed full-time
# 24                                 Employed full-time
# 25                                 Employed full-time
# 26                                 Employed full-time
#
#                                             Ethnicity Gender  \
# 0                              Hispanic or Latino/a/x    Man
# 1                        White or of European descent    Man
# 2                        White or of European descent    Man
# 3                        White or of European descent    Man
# 4                        White or of European descent    Man
# 5                        White or of European descent    Man
# 6                        White or of European descent    Man
# 7                        White or of European descent    Man
# 8                        White or of European descent    Man
# 9                        White or of European descent    Man
# 10                                               None    Man
# 11                             Hispanic or Latino/a/x    Man
# 12  Hispanic or Latino/a/x;White or of European de...    Man
# 13                       White or of European descent    Man
# 14                       White or of European descent    Man
# 15                             Hispanic or Latino/a/x    Man
# 16                       White or of European descent  Woman
# 17                                               None    Man
# 18                       White or of European descent    Man
# 19                       White or of European descent    Man
# 20                       White or of European descent    Man
# 21                       White or of European descent    Man
# 22                             Hispanic or Latino/a/x    Man
# 23                             Hispanic or Latino/a/x    Man
# 24                       White or of European descent    Man
# 25                       White or of European descent    Man
# 26                             Hispanic or Latino/a/x    Man
#
#                                            JobFactors                 JobSat  \
# 0   Industry that I’d be working in;Flex time or a...  Slightly dissatisfied
# 1   Languages, frameworks, and other technologies ...         Very satisfied
# 2   Remote work options;Opportunities for professi...         Very satisfied
# 3   Languages, frameworks, and other technologies ...         Very satisfied
# 4   How widely used or impactful my work output wo...         Very satisfied
# 5   Flex time or a flexible schedule;Languages, fr...     Slightly satisfied
# 6                                                None                   None
# 7   Remote work options;Office environment or comp...     Slightly satisfied
# 8   Flex time or a flexible schedule;Languages, fr...         Very satisfied
# 9   Languages, frameworks, and other technologies ...     Slightly satisfied
# 10  Flex time or a flexible schedule;Remote work o...     Slightly satisfied
# 11  Languages, frameworks, and other technologies ...     Slightly satisfied
# 12                                               None                   None
# 13  Specific department or team I’d be working on;...     Slightly satisfied
# 14  Industry that I’d be working in;Languages, fra...         Very satisfied
# 15  Flex time or a flexible schedule;Languages, fr...     Slightly satisfied
# 16                                               None                   None
# 17                                               None                   None
# 18  Flex time or a flexible schedule;Languages, fr...      Very dissatisfied
# 19  Flex time or a flexible schedule;Languages, fr...                   None
# 20  Industry that I’d be working in;Flex time or a...         Very satisfied
# 21  Specific department or team I’d be working on;...  Slightly dissatisfied
# 22  Languages, frameworks, and other technologies ...     Slightly satisfied
# 23  Flex time or a flexible schedule;Remote work o...      Very dissatisfied
# 24  Industry that I’d be working in;Remote work op...      Very dissatisfied
# 25                                               None         Very satisfied
# 26  Flex time or a flexible schedule;Specific depa...         Very satisfied
#
#                                               JobSeek  \
# 0        I am not interested in new job opportunities
# 1        I am not interested in new job opportunities
# 2        I am not interested in new job opportunities
# 3        I am not interested in new job opportunities
# 4   I’m not actively looking, but I am open to new...
# 5   I’m not actively looking, but I am open to new...
# 6                                                None
# 7   I’m not actively looking, but I am open to new...
# 8   I’m not actively looking, but I am open to new...
# 9   I’m not actively looking, but I am open to new...
# 10  I’m not actively looking, but I am open to new...
# 11  I’m not actively looking, but I am open to new...
# 12                                               None
# 13  I’m not actively looking, but I am open to new...
# 14       I am not interested in new job opportunities
# 15  I’m not actively looking, but I am open to new...
# 16                                               None
# 17  I’m not actively looking, but I am open to new...
# 18       I am not interested in new job opportunities
# 19                    I am actively looking for a job
# 20  I’m not actively looking, but I am open to new...
# 21  I’m not actively looking, but I am open to new...
# 22  I’m not actively looking, but I am open to new...
# 23  I’m not actively looking, but I am open to new...
# 24                    I am actively looking for a job
# 25       I am not interested in new job opportunities
# 26  I’m not actively looking, but I am open to new...
#
#                                LanguageDesireNextYear  \
# 0                                                None
# 1                               Bash/Shell/PowerShell
# 2                                          Python;SQL
# 3                                      Haskell;Python
# 4             C#;HTML/CSS;Java;JavaScript;PHP;SQL;VBA
# 5                                  Haskell;JavaScript
# 6          HTML/CSS;JavaScript;Python;Rust;TypeScript
# 7                           HTML/CSS;PHP;Python;R;SQL
# 8                                   Java;Kotlin;Scala
# 9          C;C++;HTML/CSS;JavaScript;PHP;Python;R;SQL
# 10                 HTML/CSS;JavaScript;PHP;TypeScript
# 11                                   Java;Kotlin;Rust
# 12                 Go;Java;JavaScript;Kotlin;Python;R
# 13  Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;...
# 14       C#;C++;HTML/CSS;JavaScript;Kotlin;Python;SQL
# 15                       HTML/CSS;Java;JavaScript;SQL
# 16                            HTML/CSS;JavaScript;SQL
# 17                 HTML/CSS;JavaScript;PHP;Python;SQL
# 18           Bash/Shell/PowerShell;C++;PHP;Python;SQL
# 19                   Bash/Shell/PowerShell;C#;C++;SQL
# 20                     C++;HTML/CSS;JavaScript;Python
# 21      Bash/Shell/PowerShell;C;C++;Go;Haskell;Python
# 22                                            Haskell
# 23                           C#;Go;Java;Kotlin;Python
# 24                                              R;SQL
# 25  Bash/Shell/PowerShell;HTML/CSS;JavaScript;SQL;VBA
# 26                                        C#;Go;Swift
#
#                                    LanguageWorkedWith  \
# 0                                              C#;SQL
# 1      Bash/Shell/PowerShell;HTML/CSS;Java;Python;SQL
# 2                                                 SQL
# 3                      C++;Dart;Java;Kotlin;SQL;Swift
# 4                  C#;HTML/CSS;JavaScript;PHP;SQL;VBA
# 5                                  Haskell;JavaScript
# 6                          HTML/CSS;JavaScript;Python
# 7                             HTML/CSS;PHP;Python;SQL
# 8                  HTML/CSS;Java;JavaScript;Scala;SQL
# 9              C;HTML/CSS;JavaScript;PHP;Python;R;SQL
# 10                            HTML/CSS;JavaScript;PHP
# 11                                        Java;Kotlin
# 12                    Java;JavaScript;Kotlin;Python;R
# 13      Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP
# 14             C#;HTML/CSS;Java;JavaScript;Python;SQL
# 15                       HTML/CSS;Java;JavaScript;SQL
# 16                        HTML/CSS;JavaScript;PHP;SQL
# 17                  C++;HTML/CSS;JavaScript;PHP;R;SQL
# 18               Bash/Shell/PowerShell;C++;Python;SQL
# 19   Bash/Shell/PowerShell;C#;C++;Java;JavaScript;SQL
# 20                     C++;HTML/CSS;JavaScript;Python
# 21  Assembly;Bash/Shell/PowerShell;C;C++;HTML/CSS;...
# 22             Bash/Shell/PowerShell;Haskell;HTML/CSS
# 23                                                SQL
# 24                                              R;SQL
# 25  Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;...
# 26  C;Dart;HTML/CSS;Java;JavaScript;PHP;SQL;TypeSc...
#
#                         MiscTechDesireNextYear            MiscTechWorkedWith  \
# 0                                         None                          .NET
# 1                                         None                          None
# 2                                         None                          None
# 3                                         None                       Flutter
# 4                       .NET;.NET Core;Xamarin                          .NET
# 5                                         None                          None
# 6                                      Node.js                       Node.js
# 7                                       Pandas                        Pandas
# 8                                         None                          None
# 9       Hadoop;Keras;Node.js;Pandas;TensorFlow                       Node.js
# 10                                     Node.js                       Node.js
# 11               Apache Spark;Keras;TensorFlow                       Node.js
# 12                                        None                       Node.js
# 13                                        None                          None
# 14  .NET Core;Node.js;TensorFlow;Torch/PyTorch     .NET Core;Cordova;Node.js
# 15                                        None                          None
# 16                                        None                          None
# 17                                        None                          None
# 18                                        None                          None
# 19                              .NET;.NET Core                          .NET
# 20       Keras;Pandas;TensorFlow;Torch/PyTorch       Keras;Pandas;TensorFlow
# 21                                     Node.js                       Node.js
# 22                                        None                          None
# 23                                        None                          None
# 24                                        None                          None
# 25                                        None                          None
# 26   .NET;Cordova;Flutter;Node.js;React Native  .NET;Cordova;Flutter;Node.js
#
#                          NEWCollabToolsDesireNextYear  \
# 0                                                None
# 1         Github;Slack;Google Suite (Docs, Meet, etc)
# 2   Confluence;Jira;Github;Slack;Microsoft Teams;T...
# 3                                                None
# 4   Github;Microsoft Teams;Microsoft Azure;Trello;...
# 5                                        Github;Slack
# 6                                        Github;Slack
# 7   Github;Slack;Trello;Google Suite (Docs, Meet, ...
# 8                              Confluence;Jira;Github
# 9                                                None
# 10                                             Github
# 11                                             Github
# 12                                               None
# 13       Github;Trello;Google Suite (Docs, Meet, etc)
# 14                                      Github;Gitlab
# 15                        Jira;Github;Microsoft Teams
# 16                                               None
# 17              Github;Google Suite (Docs, Meet, etc)
# 18                     Google Suite (Docs, Meet, etc)
# 19                      Github;Gitlab;Microsoft Azure
# 20  Confluence;Jira;Github;Gitlab;Microsoft Teams;...
# 21  Confluence;Jira;Github;Gitlab;Microsoft Teams;...
# 22  Github;Gitlab;Slack;Google Suite (Docs, Meet, ...
# 23                                               None
# 24       Github;Trello;Google Suite (Docs, Meet, etc)
# 25       Github;Gitlab;Google Suite (Docs, Meet, etc)
# 26                                      Gitlab;Trello
#
#                              NEWCollabToolsWorkedWith NEWDevOps  \
# 0                              Github;Microsoft Teams        No
# 1         Github;Slack;Google Suite (Docs, Meet, etc)       Yes
# 2   Confluence;Jira;Github;Slack;Microsoft Teams;T...        No
# 3   Confluence;Jira;Github;Slack;Google Suite (Doc...       Yes
# 4                                       Github;Trello       Yes
# 5                                   Jira;Github;Slack        No
# 6                                        Github;Slack      None
# 7                 Github;Slack;Microsoft Teams;Trello       Yes
# 8                              Confluence;Jira;Github       Yes
# 9                                                None        No
# 10                                             Github        No
# 11  Confluence;Jira;Github;Gitlab;Slack;Microsoft ...       Yes
# 12                                               None      None
# 13   Jira;Github;Slack;Google Suite (Docs, Meet, etc)       Yes
# 14                                      Github;Gitlab        No
# 15      Confluence;Jira;Github;Gitlab;Microsoft Teams       Yes
# 16                                               None      None
# 17              Github;Google Suite (Docs, Meet, etc)      None
# 18                     Google Suite (Docs, Meet, etc)        No
# 19  Jira;Github;Gitlab;Microsoft Teams;Microsoft A...      None
# 20  Confluence;Jira;Github;Gitlab;Microsoft Teams;...       Yes
# 21  Confluence;Github;Gitlab;Microsoft Teams;Micro...       Yes
# 22  Github;Gitlab;Slack;Trello;Google Suite (Docs,...       Yes
# 23                                               None  Not sure
# 24       Github;Trello;Google Suite (Docs, Meet, etc)        No
# 25       Github;Gitlab;Google Suite (Docs, Meet, etc)        No
# 26               Github;Gitlab;Microsoft Teams;Trello        No
#
#            NEWDevOpsImpt                           NEWEdImpt  \
# 0     Somewhat important                      Very important
# 1    Extremely important                      Very important
# 2                Neutral                      Very important
# 3    Extremely important                    Fairly important
# 4    Extremely important                Critically important
# 5     Somewhat important                    Fairly important
# 6                   None                      Very important
# 7    Extremely important                      Very important
# 8    Extremely important                Critically important
# 9                Neutral                Critically important
# 10   Extremely important  Not at all important/not necessary
# 11   Extremely important                      Very important
# 12                  None                Critically important
# 13               Neutral                      Very important
# 14    Somewhat important                  Somewhat important
# 15    Somewhat important                      Very important
# 16                  None  Not at all important/not necessary
# 17                  None  Not at all important/not necessary
# 18               Neutral                      Very important
# 19                  None  Not at all important/not necessary
# 20   Extremely important                Critically important
# 21   Extremely important                      Very important
# 22    Somewhat important                      Very important
# 23    Somewhat important                      Very important
# 24  Not at all important                                None
# 25                  None                      Very important
# 26    Somewhat important                Critically important
#
#                                            NEWJobHunt  \
# 0   Curious about other opportunities;Better compe...
# 1   Better compensation;Wanting to work with new t...
# 2                                                None
# 3   Better work/life balance;Wanting to work with ...
# 4   Better work/life balance;Wanting to work with ...
# 5   Having a bad day (or week or month) at work;Cu...
# 6                                                None
# 7   Better compensation;Growth or leadership oppor...
# 8   Having a bad day (or week or month) at work;Be...
# 9   Curious about other opportunities;Better compe...
# 10  Curious about other opportunities;Better compe...
# 11  Better compensation;Wanting to work with new t...
# 12                                               None
# 13                                Better compensation
# 14              Wanting to work with new technologies
# 15                           Better work/life balance
# 16                                               None
# 17                                               None
# 18  Wanting to share accomplishments with a wider ...
# 19  Curious about other opportunities;Better compe...
# 20  Having a bad day (or week or month) at work;Cu...
# 21  Better compensation;Growth or leadership oppor...
# 22  Wanting to share accomplishments with a wider ...
# 23  Curious about other opportunities;Better compe...
# 24  Better work/life balance;Wanting to work with ...
# 25                                               None
# 26  Curious about other opportunities;Better compe...
#
#                                    NEWJobHuntResearch              NEWLearn  \
# 0                                                None         Once a decade
# 1                Personal network - friends or family  Once every few years
# 2   Company reviews from third party sites (e.g. G...  Once every few years
# 3   Read company media, such as employee blogs or ...           Once a year
# 4   Company reviews from third party sites (e.g. G...  Once every few years
# 5   Company reviews from third party sites (e.g. G...         Once a decade
# 6                                                None  Once every few years
# 7   Personal network - friends or family;Directly ...  Once every few years
# 8   Company reviews from third party sites (e.g. G...  Once every few years
# 9   Read other media like news articles, founder p...  Once every few years
# 10  Read company media, such as employee blogs or ...  Once every few years
# 11  Read company media, such as employee blogs or ...           Once a year
# 12                                               None           Once a year
# 13  Read company media, such as employee blogs or ...      Every few months
# 14  Read company media, such as employee blogs or ...      Every few months
# 15  Read company media, such as employee blogs or ...  Once every few years
# 16                                               None  Once every few years
# 17                                               None           Once a year
# 18  Read company media, such as employee blogs or ...  Once every few years
# 19  Read company media, such as employee blogs or ...           Once a year
# 20  Read company media, such as employee blogs or ...           Once a year
# 21  Read company media, such as employee blogs or ...           Once a year
# 22  Read company media, such as employee blogs or ...           Once a year
# 23  Read company media, such as employee blogs or ...  Once every few years
# 24  Publicly available financial information (e.g....         Once a decade
# 25                                               None           Once a year
# 26  Personal network - friends or family;Read othe...      Every few months
#
#    NEWOffTopic                NEWOnboardGood NEWOtherComms  \
# 0     Not sure                           Yes           Yes
# 1           No                           Yes            No
# 2          Yes  Onboarding? What onboarding?           Yes
# 3           No                           Yes           Yes
# 4           No                           Yes            No
# 5     Not sure  Onboarding? What onboarding?           Yes
# 6     Not sure                          None            No
# 7           No  Onboarding? What onboarding?            No
# 8          Yes                           Yes            No
# 9     Not sure                           Yes            No
# 10    Not sure                           Yes            No
# 11          No                           Yes            No
# 12         Yes                          None            No
# 13          No                           Yes           Yes
# 14          No  Onboarding? What onboarding?            No
# 15        None                           Yes           Yes
# 16         Yes                          None           Yes
# 17          No                          None            No
# 18    Not sure                           Yes            No
# 19         Yes                          None           Yes
# 20         Yes  Onboarding? What onboarding?            No
# 21    Not sure                           Yes            No
# 22    Not sure                            No           Yes
# 23    Not sure                            No            No
# 24          No  Onboarding? What onboarding?            No
# 25        None                          None            No
# 26    Not sure                           Yes            No
#
#                                           NEWOvertime  \
# 0                    Often: 1-2 days per week or more
# 1   Sometimes: 1-2 days per month but less than we...
# 2                    Often: 1-2 days per week or more
# 3                   Rarely: 1-2 days per year or less
# 4                    Often: 1-2 days per week or more
# 5   Sometimes: 1-2 days per month but less than we...
# 6                                                None
# 7   Sometimes: 1-2 days per month but less than we...
# 8   Occasionally: 1-2 days per quarter but less th...
# 9   Occasionally: 1-2 days per quarter but less th...
# 10                                              Never
# 11  Occasionally: 1-2 days per quarter but less th...
# 12                                               None
# 13  Occasionally: 1-2 days per quarter but less th...
# 14                   Often: 1-2 days per week or more
# 15  Sometimes: 1-2 days per month but less than we...
# 16                                               None
# 17                                               None
# 18  Occasionally: 1-2 days per quarter but less th...
# 19                                               None
# 20  Sometimes: 1-2 days per month but less than we...
# 21                  Rarely: 1-2 days per year or less
# 22  Sometimes: 1-2 days per month but less than we...
# 23                  Rarely: 1-2 days per year or less
# 24                                              Never
# 25  Sometimes: 1-2 days per month but less than we...
# 26                   Often: 1-2 days per week or more
#
#                                   NEWPurchaseResearch      NEWPurpleLink  \
# 0   Ask developers I know/work with;Visit develope...        Indifferent
# 1                                                None  Hello, old friend
# 2                                  Start a free trial        Indifferent
# 3   Start a free trial;Ask developers I know/work ...  Hello, old friend
# 4   Start a free trial;Ask developers I know/work ...             Amused
# 5                                  Start a free trial             Amused
# 6   Start a free trial;Visit developer communities...            Annoyed
# 7   Start a free trial;Ask developers I know/work ...  Hello, old friend
# 8                                                None        Indifferent
# 9                                                None  Hello, old friend
# 10                                 Start a free trial  Hello, old friend
# 11  Ask developers I know/work with;Visit develope...  Hello, old friend
# 12  Start a free trial;Visit developer communities...  Hello, old friend
# 13  Start a free trial;Ask developers I know/work ...  Hello, old friend
# 14  Ask developers I know/work with;Visit develope...  Hello, old friend
# 15                                               None             Amused
# 16                                               None        Indifferent
# 17  Start a free trial;Ask developers I know/work ...        Indifferent
# 18  Start a free trial;Ask developers I know/work ...        Indifferent
# 19  Start a free trial;Ask developers I know/work ...        Indifferent
# 20  Start a free trial;Ask developers I know/work ...             Amused
# 21  Start a free trial;Ask developers I know/work ...  Hello, old friend
# 22  Ask developers I know/work with;Visit develope...  Hello, old friend
# 23                                               None               None
# 24                                               None        Indifferent
# 25  Start a free trial;Ask developers I know/work ...               None
# 26  Start a free trial;Ask developers I know/work ...  Hello, old friend
#
#                                            NEWSOSites  \
# 0   Stack Overflow (public Q&A for anyone who code...
# 1   Stack Overflow (public Q&A for anyone who code...
# 2    Stack Overflow (public Q&A for anyone who codes)
# 3   Stack Overflow (public Q&A for anyone who code...
# 4   Stack Overflow (public Q&A for anyone who code...
# 5   Stack Overflow (public Q&A for anyone who code...
# 6   Stack Overflow (public Q&A for anyone who code...
# 7    Stack Overflow (public Q&A for anyone who codes)
# 8    Stack Overflow (public Q&A for anyone who codes)
# 9    Stack Overflow (public Q&A for anyone who codes)
# 10  Stack Overflow (public Q&A for anyone who code...
# 11   Stack Overflow (public Q&A for anyone who codes)
# 12   Stack Overflow (public Q&A for anyone who codes)
# 13  Stack Overflow (public Q&A for anyone who code...
# 14   Stack Overflow (public Q&A for anyone who codes)
# 15            I have never visited any of these sites
# 16  Stack Overflow (public Q&A for anyone who code...
# 17  Stack Overflow (public Q&A for anyone who code...
# 18  Stack Overflow (public Q&A for anyone who code...
# 19  Stack Overflow (public Q&A for anyone who code...
# 20  Stack Overflow (public Q&A for anyone who code...
# 21  Stack Overflow (public Q&A for anyone who code...
# 22  Stack Overflow (public Q&A for anyone who code...
# 23  Stack Overflow (public Q&A for anyone who code...
# 24   Stack Overflow (public Q&A for anyone who codes)
# 25   Stack Overflow (public Q&A for anyone who codes)
# 26   Stack Overflow (public Q&A for anyone who codes)
#
#                                              NEWStuck        OpSys  \
# 0   Call a coworker or friend;Visit Stack Overflow...      Windows
# 1   Visit Stack Overflow;Go for a walk or other ph...        MacOS
# 2      Call a coworker or friend;Visit Stack Overflow      Windows
# 3   Visit Stack Overflow;Go for a walk or other ph...        MacOS
# 4   Visit Stack Overflow;Watch help / tutorial videos      Windows
# 5   Call a coworker or friend;Visit Stack Overflow...        MacOS
# 6   Play games;Visit Stack Overflow;Watch help / t...  Linux-based
# 7                                Visit Stack Overflow  Linux-based
# 8   Visit Stack Overflow;Go for a walk or other ph...  Linux-based
# 9   Play games;Visit Stack Overflow;Go for a walk ...  Linux-based
# 10  Visit Stack Overflow;Watch help / tutorial videos  Linux-based
# 11  Call a coworker or friend;Visit Stack Overflow...      Windows
# 12  Meditate;Visit Stack Overflow;Go for a walk or...      Windows
# 13  Meditate;Call a coworker or friend;Visit Stack...        MacOS
# 14  Visit Stack Overflow;Go for a walk or other ph...  Linux-based
# 15  Visit Stack Overflow;Watch help / tutorial vid...      Windows
# 16  Watch help / tutorial videos;Do other work and...        MacOS
# 17  Play games;Visit Stack Overflow;Panic;Watch he...  Linux-based
# 18  Call a coworker or friend;Visit Stack Overflow...      Windows
# 19  Visit Stack Overflow;Watch help / tutorial vid...      Windows
# 20  Call a coworker or friend;Visit Stack Overflow...  Linux-based
# 21  Meditate;Play games;Call a coworker or friend;...  Linux-based
# 22  Visit Stack Overflow;Go for a walk or other ph...  Linux-based
# 23  Visit Stack Overflow;Watch help / tutorial vid...      Windows
# 24  Meditate;Visit Stack Overflow;Visit another de...      Windows
# 25  Visit Stack Overflow;Watch help / tutorial videos      Windows
# 26                               Visit Stack Overflow        MacOS
#
#                      OrgSize  \
# 0       100 to 499 employees
# 1         20 to 99 employees
# 2           2 to 9 employees
# 3       100 to 499 employees
# 4           2 to 9 employees
# 5           2 to 9 employees
# 6                       None
# 7         20 to 99 employees
# 8       100 to 499 employees
# 9   1,000 to 4,999 employees
# 10        10 to 19 employees
# 11  10,000 or more employees
# 12                      None
# 13        20 to 99 employees
# 14      100 to 499 employees
# 15  1,000 to 4,999 employees
# 16                      None
# 17                      None
# 18          2 to 9 employees
# 19                      None
# 20  5,000 to 9,999 employees
# 21  10,000 or more employees
# 22  1,000 to 4,999 employees
# 23      100 to 499 employees
# 24        10 to 19 employees
# 25      100 to 499 employees
# 26        20 to 99 employees
#
#                                PlatformDesireNextYear  \
# 0                                                None
# 1                                         Linux;MacOS
# 2                     Android;Microsoft Azure;Windows
# 3                                  MacOS;Raspberry Pi
# 4   Android;Google Cloud Platform;Microsoft Azure;...
# 5                                 Linux;MacOS;Windows
# 6                             AWS;Docker;Heroku;Linux
# 7   Google Cloud Platform;Linux;Raspberry Pi;WordP...
# 8             Docker;Google Cloud Platform;Kubernetes
# 9                              Heroku;Linux;WordPress
# 10                                             Docker
# 11                              AWS;Docker;Kubernetes
# 12                              Android;Linux;Windows
# 13                                          WordPress
# 14                          Android;AWS;Linux;Windows
# 15                                      Linux;Windows
# 16                                               None
# 17                Google Cloud Platform;Linux;Windows
# 18                                            Windows
# 19                        Android;Linux;MacOS;Windows
# 20   Arduino;AWS;Docker;Kubernetes;Linux;Raspberry Pi
# 21  AWS;Docker;Google Cloud Platform;iOS;Kubernete...
# 22                                       Docker;Linux
# 23                                            Windows
# 24            AWS;Google Cloud Platform;Linux;Windows
# 25                      Android;Google Cloud Platform
# 26                Android;Docker;iOS;Kubernetes;MacOS
#
#                                    PlatformWorkedWith  \
# 0                                             Windows
# 1                                         Linux;MacOS
# 2                     Android;Microsoft Azure;Windows
# 3                                 Android;Arduino;iOS
# 4                                   Windows;WordPress
# 5                                 Linux;MacOS;Windows
# 6   AWS;Docker;Google Cloud Platform;Heroku;Kubern...
# 7               Google Cloud Platform;Linux;WordPress
# 8                        Docker;Google Cloud Platform
# 9                              Heroku;Linux;WordPress
# 10                                             Docker
# 11  Docker;Google Cloud Platform;Kubernetes;Linux;...
# 12                                      Linux;Windows
# 13                                          WordPress
# 14  AWS;Google Cloud Platform;Linux;Microsoft Azur...
# 15                                      Linux;Windows
# 16                                               None
# 17                Google Cloud Platform;Linux;Windows
# 18                                            Windows
# 19                        Android;Linux;MacOS;Windows
# 20           AWS;Docker;Kubernetes;Linux;Raspberry Pi
# 21  Android;Arduino;AWS;Docker;Google Cloud Platfo...
# 22                                              Linux
# 23                                            Windows
# 24            AWS;Google Cloud Platform;Linux;Windows
# 25                      Android;Google Cloud Platform
# 26  Android;AWS;Docker;Google Cloud Platform;iOS;L...
#
#                         PurchaseWhat                Sexuality  \
# 0   I have a great deal of influence  Straight / Heterosexual
# 1      I have little or no influence  Straight / Heterosexual
# 2                               None  Straight / Heterosexual
# 3                               None  Straight / Heterosexual
# 4                               None  Straight / Heterosexual
# 5                               None  Straight / Heterosexual
# 6                               None  Straight / Heterosexual
# 7              I have some influence                     None
# 8      I have little or no influence  Straight / Heterosexual
# 9              I have some influence  Straight / Heterosexual
# 10  I have a great deal of influence                     None
# 11             I have some influence  Straight / Heterosexual
# 12                              None  Straight / Heterosexual
# 13  I have a great deal of influence  Straight / Heterosexual
# 14  I have a great deal of influence  Straight / Heterosexual
# 15     I have little or no influence  Straight / Heterosexual
# 16                              None                     None
# 17                              None  Straight / Heterosexual
# 18                              None                     None
# 19                              None                     None
# 20             I have some influence  Straight / Heterosexual
# 21             I have some influence                     None
# 22             I have some influence  Straight / Heterosexual
# 23     I have little or no influence                     None
# 24     I have little or no influence  Straight / Heterosexual
# 25  I have a great deal of influence                     None
# 26             I have some influence  Straight / Heterosexual
#
#                   SOAccount           SOComm  \
# 0                       Yes  Yes, definitely
# 1                       Yes  Yes, definitely
# 2   Not sure/can't remember   No, not really
# 3                       Yes          Neutral
# 4                       Yes    Yes, somewhat
# 5                       Yes    Yes, somewhat
# 6                       Yes   No, not really
# 7                       Yes    Yes, somewhat
# 8                       Yes          Neutral
# 9                       Yes    Yes, somewhat
# 10                      Yes   No, not really
# 11                      Yes    Yes, somewhat
# 12                      Yes    Yes, somewhat
# 13                      Yes    Yes, somewhat
# 14                       No   No, not at all
# 15                     None             None
# 16                      Yes    Yes, somewhat
# 17                      Yes   No, not at all
# 18                      Yes   No, not really
# 19                      Yes    Yes, somewhat
# 20                      Yes    Yes, somewhat
# 21                      Yes   No, not really
# 22                      Yes   No, not really
# 23  Not sure/can't remember   No, not really
# 24                      Yes          Neutral
# 25                      Yes          Neutral
# 26  Not sure/can't remember    Yes, somewhat
#
#                                            SOPartFreq  \
# 0                              Multiple times per day
# 1                                A few times per week
# 2                                                None
# 3                     A few times per month or weekly
# 4                     A few times per month or weekly
# 5                 Less than once per month or monthly
# 6   I have never participated in Q&A on Stack Over...
# 7                 Less than once per month or monthly
# 8                 Less than once per month or monthly
# 9                 Less than once per month or monthly
# 10                Less than once per month or monthly
# 11                Less than once per month or monthly
# 12                Less than once per month or monthly
# 13                    A few times per month or weekly
# 14                                               None
# 15                                               None
# 16                              Daily or almost daily
# 17  I have never participated in Q&A on Stack Over...
# 18                Less than once per month or monthly
# 19                               A few times per week
# 20                    A few times per month or weekly
# 21  I have never participated in Q&A on Stack Over...
# 22                Less than once per month or monthly
# 23                                               None
# 24                Less than once per month or monthly
# 25                Less than once per month or monthly
# 26                                               None
#
#                             SOVisitFreq                  SurveyEase  \
# 0                 Daily or almost daily                        Easy
# 1                Multiple times per day                        Easy
# 2                 Daily or almost daily                        Easy
# 3                Multiple times per day                        Easy
# 4                 Daily or almost daily                        Easy
# 5   Less than once per month or monthly                        Easy
# 6       A few times per month or weekly                        Easy
# 7                Multiple times per day  Neither easy nor difficult
# 8                 Daily or almost daily                        Easy
# 9       A few times per month or weekly                        Easy
# 10                Daily or almost daily  Neither easy nor difficult
# 11                 A few times per week  Neither easy nor difficult
# 12      A few times per month or weekly                        Easy
# 13                Daily or almost daily                        Easy
# 14               Multiple times per day                        None
# 15                                 None                        Easy
# 16                Daily or almost daily  Neither easy nor difficult
# 17      A few times per month or weekly                        Easy
# 18                 A few times per week                        Easy
# 19                Daily or almost daily  Neither easy nor difficult
# 20               Multiple times per day  Neither easy nor difficult
# 21                Daily or almost daily                        Easy
# 22                 A few times per week                        Easy
# 23                Daily or almost daily  Neither easy nor difficult
# 24      A few times per month or weekly                        Easy
# 25      A few times per month or weekly  Neither easy nor difficult
# 26                 A few times per week  Neither easy nor difficult
#
#              SurveyLength Trans  \
# 0                Too long    No
# 1   Appropriate in length    No
# 2   Appropriate in length    No
# 3   Appropriate in length    No
# 4   Appropriate in length    No
# 5   Appropriate in length    No
# 6   Appropriate in length    No
# 7                Too long  None
# 8                Too long    No
# 9   Appropriate in length    No
# 10               Too long  None
# 11               Too long    No
# 12  Appropriate in length    No
# 13  Appropriate in length    No
# 14              Too short    No
# 15  Appropriate in length    No
# 16                   None    No
# 17               Too long    No
# 18  Appropriate in length    No
# 19               Too long    No
# 20  Appropriate in length    No
# 21               Too long  None
# 22  Appropriate in length    No
# 23  Appropriate in length  None
# 24               Too long    No
# 25               Too long    No
# 26               Too long    No
#
#                                        UndergradMajor  \
# 0                                                None
# 1   Computer science, computer engineering, or sof...
# 2   Another engineering discipline (such as civil,...
# 3   Another engineering discipline (such as civil,...
# 4   Computer science, computer engineering, or sof...
# 5   Computer science, computer engineering, or sof...
# 6   Computer science, computer engineering, or sof...
# 7   Information systems, information technology, o...
# 8   Computer science, computer engineering, or sof...
# 9   A humanities discipline (such as literature, h...
# 10  Computer science, computer engineering, or sof...
# 11  Another engineering discipline (such as civil,...
# 12  A health science (such as nursing, pharmacy, r...
# 13  A social science (such as anthropology, psycho...
# 14  Computer science, computer engineering, or sof...
# 15  Computer science, computer engineering, or sof...
# 16  A natural science (such as biology, chemistry,...
# 17  Computer science, computer engineering, or sof...
# 18  Computer science, computer engineering, or sof...
# 19  A natural science (such as biology, chemistry,...
# 20  A natural science (such as biology, chemistry,...
# 21  Computer science, computer engineering, or sof...
# 22  A health science (such as nursing, pharmacy, r...
# 23  Computer science, computer engineering, or sof...
# 24  A business discipline (such as accounting, fin...
# 25  Computer science, computer engineering, or sof...
# 26  Computer science, computer engineering, or sof...
#
#                           WebframeDesireNextYear  \
# 0                                           None
# 1                                           None
# 2                                           None
# 3                                           None
# 4         Angular.js;ASP.NET;ASP.NET Core;jQuery
# 5                                           None
# 6   Angular;Django;Express;Flask;Gatsby;React.js
# 7                                           None
# 8                                           None
# 9                         Django;Gatsby;React.js
# 10                              Express;React.js
# 11                                        Spring
# 12                     Angular;Angular.js;jQuery
# 13               Express;Laravel;React.js;Vue.js
# 14                      Angular.js;Django;jQuery
# 15                                        Spring
# 16                                          None
# 17                                        jQuery
# 18                                        Django
# 19                                          None
# 20                                  Django;Flask
# 21                                          None
# 22                                          None
# 23                                          None
# 24                                          None
# 25                                          None
# 26                              Angular;React.js
#
#                                WebframeWorkedWith  \
# 0                                         ASP.NET
# 1                                          Django
# 2                                            None
# 3                                            None
# 4                       Angular.js;ASP.NET;jQuery
# 5                                            None
# 6                         Express;Gatsby;React.js
# 7                                            None
# 8                                            None
# 9                                 Gatsby;React.js
# 10                        Drupal;Express;React.js
# 11                                 Angular;Spring
# 12                                         jQuery
# 13                               Laravel;React.js
# 14                                  Django;jQuery
# 15                                         Spring
# 16                         jQuery;React.js;Vue.js
# 17                                         jQuery
# 18                                         Django
# 19                                 ASP.NET;jQuery
# 20                                          Flask
# 21                                           None
# 22                                           None
# 23                                           None
# 24                                           None
# 25                                         Spring
# 26  Angular;ASP.NET;jQuery;Laravel;Spring;Symfony
#
#                                WelcomeChange  WorkWeekHrs YearsCode  \
# 0   Somewhat less welcome now than last year         50.0        40
# 1    Just as welcome now as I felt last year         40.0        30
# 2    Just as welcome now as I felt last year         40.0        38
# 3    Just as welcome now as I felt last year         50.0        43
# 4      A lot more welcome now than last year         60.0        35
# 5    Just as welcome now as I felt last year         20.0        38
# 6    Just as welcome now as I felt last year          NaN        37
# 7    Just as welcome now as I felt last year         40.0        30
# 8   Somewhat less welcome now than last year         40.0        31
# 9    Just as welcome now as I felt last year         40.0        30
# 10   Just as welcome now as I felt last year         40.0        32
# 11   Just as welcome now as I felt last year         40.0        40
# 12  Somewhat more welcome now than last year          NaN        40
# 13   Just as welcome now as I felt last year         37.0        29
# 14   Just as welcome now as I felt last year         45.0        46
# 15                                      None         40.0        30
# 16   Just as welcome now as I felt last year          NaN        10
# 17   Just as welcome now as I felt last year          NaN        42
# 18   Just as welcome now as I felt last year         40.0        40
# 19  Somewhat less welcome now than last year          NaN        44
# 20   Just as welcome now as I felt last year         40.0        45
# 21   Just as welcome now as I felt last year         40.0        30
# 22   Just as welcome now as I felt last year         37.0        31
# 23  Somewhat less welcome now than last year         40.0        30
# 24   Just as welcome now as I felt last year         60.0         5
# 25                                      None         40.0        32
# 26   Just as welcome now as I felt last year         40.0        41
#
#         YearsCodePro
# 0                 32
# 1                 25
# 2                 30
# 3                 14
# 4                 33
# 5                 30
# 6               None
# 7                  3
# 8                 20
# 9                 25
# 10                30
# 11                25
# 12              None
# 13                29
# 14                42
# 15                20
# 16              None
# 17                10
# 18                32
# 19              None
# 20                35
# 21                20
# 22                31
# 23                25
# 24  Less than 1 year
# 25                25
# 26                 6

# %% [markdown]
# ### Grupowanie i funkcje agregujące

# %%
from pyspark.sql.functions import *
df.groupBy("Country").count().show()   # dokonaj grupowania po Country i zlicz liczbe respondentow
# Out:
# +--------------------+-----+
# |             Country|count|
# +--------------------+-----+
# |       Côte d'Ivoire|   17|
# |            Paraguay|   26|
# |The former Yugosl...|   38|
# |               Yemen|    7|
# |             Senegal|   26|
# |              Sweden|  886|
# |  Hong Kong (S.A.R.)|  111|
# |   Republic of Korea|   88|
# |         Philippines|  405|
# |             Eritrea|    3|
# |           Singapore|  228|
# |            Malaysia|  231|
# |              Turkey|  777|
# |              Malawi|    8|
# |                Iraq|   44|
# |             Germany| 3890|
# |         Afghanistan|   84|
# |            Cambodia|   31|
# |              Jordan|   57|
# |            Maldives|   10|
# +--------------------+-----+
# only showing top 20 rows

# %%
df.groupBy("Country").avg("Age").show() # dokonaj grupowania po Contry i policz sredni wiek
# Out:
# +--------------------+------------------+
# |             Country|          avg(Age)|
# +--------------------+------------------+
# |       Côte d'Ivoire|25.666666666666668|
# |            Paraguay|           27.5625|
# |The former Yugosl...| 28.77777777777778|
# |               Yemen|              31.0|
# |             Senegal|29.444444444444443|
# |              Sweden| 33.77761836441894|
# |  Hong Kong (S.A.R.)| 29.78030303030303|
# |   Republic of Korea|30.434782608695652|
# |         Philippines|  25.7803738317757|
# |             Eritrea|              31.0|
# |           Singapore|28.575949367088608|
# |            Malaysia| 28.29787234042553|
# |              Turkey|29.477406679764243|
# |              Malawi|              26.0|
# |                Iraq|24.736842105263158|
# |             Germany|30.890311082307193|
# |         Afghanistan|23.545454545454547|
# |            Cambodia|              27.5|
# |              Jordan| 26.91891891891892|
# |            Maldives|18.666666666666668|
# +--------------------+------------------+
# only showing top 20 rows

# %%
df.withColumn ("Bonus", col("ConvertedComp") + 1000).filter("ConvertedComp is not NULL").toPandas() # dodaj kolumne
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               8                     I am a developer by profession      Yes
# 1              10                     I am a developer by profession      Yes
# 2              11                     I am a developer by profession      Yes
# 3              12                     I am a developer by profession       No
# 4              13  I am not primarily a developer, but I write co...      Yes
# ...           ...                                                ...      ...
# 34751       65619  I am not primarily a developer, but I write co...      Yes
# 34752       65625                     I am a developer by profession      Yes
# 34753       65629                     I am a developer by profession      Yes
# 34754       65630                     I am a developer by profession      Yes
# 34755       65631                     I am a developer by profession      Yes
#
#         Age Age1stCode CompFreq  CompTotal  ConvertedComp         Country  \
# 0      36.0         12   Yearly   116000.0       116000.0   United States
# 1      22.0         14   Yearly    25000.0        32315.0  United Kingdom
# 2      23.0         13   Yearly    31000.0        40070.0  United Kingdom
# 3      49.0         42  Monthly     1100.0        14268.0           Spain
# 4      53.0         14  Monthly     3000.0        38916.0     Netherlands
# ...     ...        ...      ...        ...            ...             ...
# 34751   NaN         19  Monthly    30000.0          984.0         Nigeria
# 34752   NaN         17  Monthly  5500000.0        19428.0        Colombia
# 34753  41.0         15   Yearly      200.0          200.0   United States
# 34754   NaN         17  Monthly  1000000.0        15048.0           Chile
# 34755   NaN         13   Yearly  4310000.0        38759.0           Japan
#
#                CurrencyDesc CurrencySymbol       DatabaseDesireNextYear  \
# 0      United States dollar            USD                      MongoDB
# 1            Pound sterling            GBP         Microsoft SQL Server
# 2            Pound sterling            GBP  Firebase;MongoDB;PostgreSQL
# 3             European Euro            EUR                         None
# 4             European Euro            EUR                         None
# ...                     ...            ...                          ...
# 34751        Nigerian naira            NGN             Firebase;MongoDB
# 34752        Colombian peso            COP                         None
# 34753  United States dollar            USD                   PostgreSQL
# 34754          Chilean peso            CLP                         None
# 34755          Japanese yen            JPY                         None
#
#                        DatabaseWorkedWith  \
# 0                     MariaDB;MySQL;Redis
# 1                    Microsoft SQL Server
# 2      Firebase;MongoDB;PostgreSQL;SQLite
# 3                                    None
# 4                                    None
# ...                                   ...
# 34751                               MySQL
# 34752                                None
# 34753                          PostgreSQL
# 34754                                None
# 34755                                None
#
#                                                  DevType  \
# 0      Developer, back-end;Developer, desktop or ente...
# 1      Database administrator;Developer, full-stack;D...
# 2      Developer, back-end;Developer, desktop or ente...
# 3                          Designer;Developer, front-end
# 4                           Designer;Developer, back-end
# ...                                                  ...
# 34751   Academic researcher;Developer, back-end;Educator
# 34752                              Developer, QA or test
# 34753  Developer, back-end;Developer, front-end;Devel...
# 34754  Developer, full-stack;Developer, QA or test;Sy...
# 34755                               Developer, front-end
#
#                                                  EdLevel          Employment  \
# 0           Bachelor’s degree (B.A., B.S., B.Eng., etc.)  Employed full-time
# 1        Master’s degree (M.A., M.S., M.Eng., MBA, etc.)  Employed full-time
# 2           Bachelor’s degree (B.A., B.S., B.Eng., etc.)  Employed full-time
# 3      Some college/university study without earning ...  Employed full-time
# 4      Secondary school (e.g. American high school, G...  Employed full-time
# ...                                                  ...                 ...
# 34751  Secondary school (e.g. American high school, G...  Employed part-time
# 34752       Bachelor’s degree (B.A., B.S., B.Eng., etc.)  Employed full-time
# 34753  Some college/university study without earning ...  Employed full-time
# 34754       Bachelor’s degree (B.A., B.S., B.Eng., etc.)  Employed full-time
# 34755       Bachelor’s degree (B.A., B.S., B.Eng., etc.)  Employed full-time
#
#                           Ethnicity Gender  \
# 0      White or of European descent    Man
# 1      White or of European descent    Man
# 2      White or of European descent    Man
# 3      White or of European descent    Man
# 4      White or of European descent    Man
# ...                             ...    ...
# 34751                          None   None
# 34752                          None   None
# 34753                          None    Man
# 34754                          None   None
# 34755                          None   None
#
#                                               JobFactors  \
# 0      Remote work options;Opportunities for professi...
# 1      Flex time or a flexible schedule;How widely us...
# 2      Flex time or a flexible schedule;Languages, fr...
# 3      Remote work options;Office environment or comp...
# 4      Industry that I’d be working in;Financial perf...
# ...                                                  ...
# 34751                                               None
# 34752  Industry that I’d be working in;Languages, fra...
# 34753  Flex time or a flexible schedule;Languages, fr...
# 34754  Languages, frameworks, and other technologies ...
# 34755                                               None
#
#                                    JobSat  \
# 0                   Slightly dissatisfied
# 1                          Very satisfied
# 2                   Slightly dissatisfied
# 3                       Very dissatisfied
# 4                          Very satisfied
# ...                                   ...
# 34751  Neither satisfied nor dissatisfied
# 34752                  Slightly satisfied
# 34753                      Very satisfied
# 34754  Neither satisfied nor dissatisfied
# 34755  Neither satisfied nor dissatisfied
#
#                                                  JobSeek  \
# 0      I’m not actively looking, but I am open to new...
# 1      I’m not actively looking, but I am open to new...
# 2                        I am actively looking for a job
# 3      I’m not actively looking, but I am open to new...
# 4           I am not interested in new job opportunities
# ...                                                  ...
# 34751                                               None
# 34752       I am not interested in new job opportunities
# 34753  I’m not actively looking, but I am open to new...
# 34754  I’m not actively looking, but I am open to new...
# 34755                                               None
#
#                       LanguageDesireNextYear  \
# 0                                 JavaScript
# 1      HTML/CSS;Java;JavaScript;Python;R;SQL
# 2             Go;JavaScript;Swift;TypeScript
# 3                        HTML/CSS;JavaScript
# 4                                     Python
# ...                                      ...
# 34751                 Dart;Python;TypeScript
# 34752                                   None
# 34753                                   None
# 34754                                   None
# 34755                                   None
#
#                         LanguageWorkedWith MiscTechDesireNextYear  \
# 0                               Python;SQL               Unity 3D
# 1      HTML/CSS;Java;JavaScript;Python;SQL      Pandas;TensorFlow
# 2                      C#;JavaScript;Swift   Node.js;React Native
# 3                      HTML/CSS;JavaScript                   .NET
# 4                      C;JavaScript;Python                   None
# ...                                    ...                    ...
# 34751   HTML/CSS;JavaScript;PHP;TypeScript  Flutter;Unreal Engine
# 34752                                 None                   None
# 34753                                 None                   None
# 34754                                 None                   None
# 34755                                 None                   None
#
#       MiscTechWorkedWith                      NEWCollabToolsDesireNextYear  \
# 0                Ansible                                              None
# 1                 Pandas                            Github;Microsoft Teams
# 2                Node.js  Jira;Github;Slack;Google Suite (Docs, Meet, etc)
# 3                   .NET                                            Github
# 4                   None                                              None
# ...                  ...                                               ...
# 34751    Cordova;Flutter                                              None
# 34752               None                                              None
# 34753               None                                            Gitlab
# 34754               None                                              None
# 34755               None                                              None
#
#                                 NEWCollabToolsWorkedWith NEWDevOps  \
# 0      Confluence;Jira;Github;Slack;Microsoft Teams;G...       Yes
# 1                                 Github;Microsoft Teams        No
# 2      Confluence;Jira;Github;Slack;Microsoft Teams;M...        No
# 3                                                 Github  Not sure
# 4                                                   None        No
# ...                                                  ...       ...
# 34751                                             Trello        No
# 34752                                               None  Not sure
# 34753                       Confluence;Jira;Github;Slack       Yes
# 34754                                               None       Yes
# 34755                                               None        No
#
#              NEWDevOpsImpt                           NEWEdImpt  \
# 0      Extremely important  Not at all important/not necessary
# 1                  Neutral                    Fairly important
# 2      Extremely important                      Very important
# 3                  Neutral                  Somewhat important
# 4                     None  Not at all important/not necessary
# ...                    ...                                 ...
# 34751   Somewhat important                  Somewhat important
# 34752   Somewhat important                    Fairly important
# 34753   Somewhat important  Not at all important/not necessary
# 34754              Neutral                      Very important
# 34755                 None                    Fairly important
#
#                                               NEWJobHunt  \
# 0      Curious about other opportunities;Better compe...
# 1      Curious about other opportunities;Better compe...
# 2      Curious about other opportunities;Better compe...
# 3                                    Better compensation
# 4            Having a bad day (or week or month) at work
# ...                                                  ...
# 34751                                               None
# 34752  Having a bad day (or week or month) at work;Cu...
# 34753  Curious about other opportunities;Better compe...
# 34754  Curious about other opportunities;Better compe...
# 34755                                               None
#
#                                       NEWJobHuntResearch  \
# 0      Read company media, such as employee blogs or ...
# 1      Company reviews from third party sites (e.g. G...
# 2      Read company media, such as employee blogs or ...
# 3      Personal network - friends or family;Directly ...
# 4      Read company media, such as employee blogs or ...
# ...                                                  ...
# 34751                                               None
# 34752  Company reviews from third party sites (e.g. G...
# 34753  Read company media, such as employee blogs or ...
# 34754  Company reviews from third party sites (e.g. G...
# 34755                                               None
#
#                    NEWLearn NEWOffTopic                NEWOnboardGood  \
# 0               Once a year    Not sure                           Yes
# 1          Every few months         Yes  Onboarding? What onboarding?
# 2          Every few months          No                           Yes
# 3      Once every few years    Not sure                            No
# 4      Once every few years          No                           Yes
# ...                     ...         ...                           ...
# 34751           Once a year        None                            No
# 34752                  None        None                           Yes
# 34753      Every few months    Not sure                           Yes
# 34754                  None        None                            No
# 34755                  None        None                           Yes
#
#       NEWOtherComms                                        NEWOvertime  \
# 0                No  Occasionally: 1-2 days per quarter but less th...
# 1                No                   Often: 1-2 days per week or more
# 2                No                  Rarely: 1-2 days per year or less
# 3                No                  Rarely: 1-2 days per year or less
# 4                No                  Rarely: 1-2 days per year or less
# ...             ...                                                ...
# 34751          None                   Often: 1-2 days per week or more
# 34752          None                  Rarely: 1-2 days per year or less
# 34753           Yes                                              Never
# 34754           Yes  Sometimes: 1-2 days per month but less than we...
# 34755          None                  Rarely: 1-2 days per year or less
#
#                                      NEWPurchaseResearch      NEWPurpleLink  \
# 0      Start a free trial;Ask developers I know/work ...  Hello, old friend
# 1      Start a free trial;Ask developers I know/work ...  Hello, old friend
# 2                                                   None            Annoyed
# 3                                                   None        Indifferent
# 4                                     Start a free trial             Amused
# ...                                                  ...                ...
# 34751  Start a free trial;Ask developers I know/work ...        Indifferent
# 34752                                               None               None
# 34753                    Ask developers I know/work with        Indifferent
# 34754                                               None               None
# 34755                                               None               None
#
#                                               NEWSOSites  \
# 0      Stack Overflow (public Q&A for anyone who code...
# 1      Stack Overflow (public Q&A for anyone who code...
# 2      Stack Overflow (public Q&A for anyone who code...
# 3      Stack Overflow (public Q&A for anyone who code...
# 4      Stack Overflow (public Q&A for anyone who code...
# ...                                                  ...
# 34751                                               None
# 34752                                               None
# 34753  Stack Overflow (public Q&A for anyone who code...
# 34754   Stack Overflow (public Q&A for anyone who codes)
# 34755                                               None
#
#                                                 NEWStuck        OpSys  \
# 0      Play games;Call a coworker or friend;Visit Sta...  Linux-based
# 1                                   Visit Stack Overflow      Windows
# 2      Play games;Call a coworker or friend;Visit Sta...      Windows
# 3                                   Visit Stack Overflow      Windows
# 4      Call a coworker or friend;Go for a walk or oth...        MacOS
# ...                                                  ...          ...
# 34751  Go for a walk or other physical activity;Watch...      Windows
# 34752                                               None         None
# 34753           Go for a walk or other physical activity        MacOS
# 34754                                               None         None
# 34755                                               None         None
#
#                         OrgSize              PlatformDesireNextYear  \
# 0            20 to 99 employees     iOS;Slack Apps and Integrations
# 1              2 to 9 employees  Android;Linux;Raspberry Pi;Windows
# 2      10,000 or more employees                AWS;Docker;iOS;MacOS
# 3              2 to 9 employees                   Windows;WordPress
# 4              2 to 9 employees                 Linux;MacOS;Windows
# ...                         ...                                 ...
# 34751          2 to 9 employees        Google Cloud Platform;Heroku
# 34752      500 to 999 employees                                None
# 34753      100 to 499 employees                  Docker;Linux;MacOS
# 34754          2 to 9 employees                                None
# 34755        20 to 99 employees                                None
#
#                        PlatformWorkedWith                      PurchaseWhat  \
# 0                                  Docker             I have some influence
# 1      Android;Linux;Raspberry Pi;Windows  I have a great deal of influence
# 2                          AWS;Heroku;iOS     I have little or no influence
# 3                       Windows;WordPress     I have little or no influence
# 4                           MacOS;Windows             I have some influence
# ...                                   ...                               ...
# 34751                   Windows;WordPress  I have a great deal of influence
# 34752                                None                              None
# 34753                  Docker;Linux;MacOS             I have some influence
# 34754                                None                              None
# 34755                                None                              None
#
#                      Sexuality SOAccount           SOComm  \
# 0      Straight / Heterosexual       Yes   No, not really
# 1      Straight / Heterosexual       Yes  Yes, definitely
# 2      Straight / Heterosexual       Yes    Yes, somewhat
# 3      Straight / Heterosexual       Yes    Yes, somewhat
# 4      Straight / Heterosexual       Yes  Yes, definitely
# ...                        ...       ...              ...
# 34751                     None      None             None
# 34752                     None      None             None
# 34753  Straight / Heterosexual       Yes    Yes, somewhat
# 34754                     None        No          Neutral
# 34755                     None      None             None
#
#                                               SOPartFreq  \
# 0                    Less than once per month or monthly
# 1                                 Multiple times per day
# 2      I have never participated in Q&A on Stack Over...
# 3                                   A few times per week
# 4                                 Multiple times per day
# ...                                                  ...
# 34751                                               None
# 34752                                               None
# 34753                Less than once per month or monthly
# 34754                                               None
# 34755                                               None
#
#                                SOVisitFreq                  SurveyEase  \
# 0                   Multiple times per day                        Easy
# 1                   Multiple times per day                        Easy
# 2                   Multiple times per day                        Easy
# 3                   Multiple times per day                        Easy
# 4                   Multiple times per day  Neither easy nor difficult
# ...                                    ...                         ...
# 34751                                 None                        None
# 34752                                 None                        None
# 34753  Less than once per month or monthly                        None
# 34754                 A few times per week                        None
# 34755                                 None                        None
#
#                 SurveyLength Trans  \
# 0      Appropriate in length    No
# 1      Appropriate in length    No
# 2      Appropriate in length    No
# 3      Appropriate in length    No
# 4                   Too long    No
# ...                      ...   ...
# 34751                   None  None
# 34752                   None  None
# 34753                   None    No
# 34754                   None  None
# 34755                   None  None
#
#                                           UndergradMajor  \
# 0      Computer science, computer engineering, or sof...
# 1                              Mathematics or statistics
# 2      Computer science, computer engineering, or sof...
# 3                              Mathematics or statistics
# 4                                                   None
# ...                                                  ...
# 34751                                               None
# 34752  Computer science, computer engineering, or sof...
# 34753  Computer science, computer engineering, or sof...
# 34754  Information systems, information technology, o...
# 34755                      Web development or web design
#
#         WebframeDesireNextYear                  WebframeWorkedWith  \
# 0       Django;React.js;Vue.js                               Flask
# 1                 Flask;jQuery                        Flask;jQuery
# 2      Angular;Django;React.js  Angular;Angular.js;Django;React.js
# 3               ASP.NET;jQuery                      ASP.NET;jQuery
# 4                         None                                None
# ...                        ...                                 ...
# 34751                  Angular                              jQuery
# 34752                     None                                None
# 34753                 React.js                            React.js
# 34754                     None                                None
# 34755                     None                                None
#
#                                   WelcomeChange  WorkWeekHrs YearsCode  \
# 0       Just as welcome now as I felt last year         39.0        17
# 1      Somewhat more welcome now than last year         36.0         8
# 2       Just as welcome now as I felt last year         40.0        10
# 3       Just as welcome now as I felt last year         40.0         7
# 4         A lot less welcome now than last year         36.0        35
# ...                                         ...          ...       ...
# 34751                                      None          4.0         3
# 34752                                      None         40.0        12
# 34753   Just as welcome now as I felt last year          NaN        25
# 34754                                      None         45.0         7
# 34755                                      None         40.0         5
#
#            YearsCodePro     Bonus
# 0                    13  117000.0
# 1                     4   33315.0
# 2                     2   41070.0
# 3                     7   15268.0
# 4                    20   39916.0
# ...                 ...       ...
# 34751                 2    1984.0
# 34752                 5   20428.0
# 34753                20    1200.0
# 34754                 3   16048.0
# 34755  Less than 1 year   39759.0
#
# [34756 rows x 62 columns]

# %%
df.drop("Age").show()  # usun kolumne Chromosome. 
# Czy DF została pozbawiona kolumny na trwale?
# Out:
# +----------+--------------------+--------+----------+--------+---------+-------------+------------------+--------------------+--------------+----------------------+--------------------+--------------------+--------------------+--------------------+--------------------+------+--------------------+--------------------+--------------------+----------------------+--------------------+----------------------+--------------------+----------------------------+------------------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+-----------+--------------------+-------------+--------------------+--------------------+-----------------+--------------------+--------------------+-----------+--------------------+----------------------+--------------------+--------------------+--------------------+---------+---------------+--------------------+--------------------+--------------------+--------------------+-----+--------------------+----------------------+--------------------+--------------------+-----------+---------+------------+
# |Respondent|          MainBranch|Hobbyist|Age1stCode|CompFreq|CompTotal|ConvertedComp|           Country|        CurrencyDesc|CurrencySymbol|DatabaseDesireNextYear|  DatabaseWorkedWith|             DevType|             EdLevel|          Employment|           Ethnicity|Gender|          JobFactors|              JobSat|             JobSeek|LanguageDesireNextYear|  LanguageWorkedWith|MiscTechDesireNextYear|  MiscTechWorkedWith|NEWCollabToolsDesireNextYear|NEWCollabToolsWorkedWith|NEWDevOps|      NEWDevOpsImpt|           NEWEdImpt|          NEWJobHunt|  NEWJobHuntResearch|            NEWLearn|NEWOffTopic|      NEWOnboardGood|NEWOtherComms|         NEWOvertime| NEWPurchaseResearch|    NEWPurpleLink|          NEWSOSites|            NEWStuck|      OpSys|             OrgSize|PlatformDesireNextYear|  PlatformWorkedWith|        PurchaseWhat|           Sexuality|SOAccount|         SOComm|          SOPartFreq|         SOVisitFreq|          SurveyEase|        SurveyLength|Trans|      UndergradMajor|WebframeDesireNextYear|  WebframeWorkedWith|       WelcomeChange|WorkWeekHrs|YearsCode|YearsCodePro|
# +----------+--------------------+--------+----------+--------+---------+-------------+------------------+--------------------+--------------+----------------------+--------------------+--------------------+--------------------+--------------------+--------------------+------+--------------------+--------------------+--------------------+----------------------+--------------------+----------------------+--------------------+----------------------------+------------------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+-----------+--------------------+-------------+--------------------+--------------------+-----------------+--------------------+--------------------+-----------+--------------------+----------------------+--------------------+--------------------+--------------------+---------+---------------+--------------------+--------------------+--------------------+--------------------+-----+--------------------+----------------------+--------------------+--------------------+-----------+---------+------------+
# |         1|I am a developer ...|     Yes|        13| Monthly|     null|         null|           Germany|       European Euro|           EUR|  Microsoft SQL Server|Elasticsearch;Mic...|Developer, deskto...|Master’s degree (...|Independent contr...|White or of Europ...|   Man|Languages, framew...|  Slightly satisfied|I am not interest...|  C#;HTML/CSS;JavaS...|C#;HTML/CSS;JavaS...|     .NET Core;Xamarin|      .NET;.NET Core|        Microsoft Teams;M...|    Confluence;Jira;S...|       No| Somewhat important|    Fairly important|                null|                null|         Once a year|   Not sure|                null|           No|Often: 1-2 days p...|Start a free tria...|           Amused|Stack Overflow (p...|Visit Stack Overf...|    Windows|    2 to 9 employees|  Android;iOS;Kuber...|             Windows|                null|Straight / Hetero...|       No| No, not at all|                null|Multiple times pe...|Neither easy nor ...|Appropriate in le...|   No|Computer science,...|          ASP.NET Core|ASP.NET;ASP.NET Core|Just as welcome n...|       50.0|       36|          27|
# |         2|I am a developer ...|      No|        19|    null|     null|         null|    United Kingdom|      Pound sterling|           GBP|                  null|                null|Developer, full-s...|Bachelor’s degree...|  Employed full-time|                null|  null|                null|   Very dissatisfied|I am not interest...|          Python;Swift|    JavaScript;Swift|  React Native;Tens...|        React Native|                Github;Slack|    Confluence;Jira;G...|     null|               null|    Fairly important|                null|                null|         Once a year|   Not sure|                null|           No|                null|                null|           Amused|Stack Overflow (p...|Visit Stack Overf...|      MacOS|1,000 to 4,999 em...|  iOS;Kubernetes;Li...|                 iOS|I have little or ...|                null|      Yes|Yes, definitely|Less than once pe...|Multiple times pe...|                null|                null| null|Computer science,...|                  null|                null|Somewhat more wel...|       null|        7|           4|
# |         3|I code primarily ...|     Yes|        15|    null|     null|         null|Russian Federation|                null|          null|                  null|                null|                null|                null|                null|                null|  null|                null|                null|                null|  Objective-C;Pytho...|Objective-C;Pytho...|                  null|                null|                        null|                    null|     null|               null|                null|                null|                null|       Once a decade|       null|                null|           No|                null|                null|             null|Stack Overflow (p...|                null|Linux-based|                null|                  null|                null|                null|                null|      Yes|  Yes, somewhat|A few times per m...|Daily or almost d...|Neither easy nor ...|Appropriate in le...| null|                null|                  null|                null|Somewhat more wel...|       null|        4|        null|
# |         4|I am a developer ...|     Yes|        18|    null|     null|         null|           Albania|        Albanian lek|           ALL|                  null|                null|                null|Master’s degree (...|                null|White or of Europ...|   Man|Flex time or a fl...|Slightly dissatis...|I’m not actively ...|                  null|                null|                  null|                null|                        null|                    null|       No|               null|Not at all import...|Curious about oth...|                null|         Once a year|   Not sure|                 Yes|          Yes|Occasionally: 1-2...|                null|             null|Stack Overflow (p...|                null|Linux-based|  20 to 99 employees|                  null|                null|I have a great de...|Straight / Hetero...|      Yes|Yes, definitely|A few times per m...|Multiple times pe...|                null|                null|   No|Computer science,...|                  null|                null|Somewhat less wel...|       40.0|        7|           4|
# |         5|I used to be a de...|     Yes|        16|    null|     null|         null|     United States|                null|          null|      MySQL;PostgreSQL|MySQL;PostgreSQL;...|                null|Bachelor’s degree...|  Employed full-time|White or of Europ...|   Man|                null|                null|                null|       Java;Ruby;Scala|   HTML/CSS;Ruby;SQL|          Ansible;Chef|             Ansible|        Github;Google Sui...|    Confluence;Jira;G...|     null|               null|      Very important|                null|                null|         Once a year|         No|                null|          Yes|                null|Start a free tria...|Hello, old friend|Stack Overflow (p...|Call a coworker o...|    Windows|                null|  Docker;Google Clo...|AWS;Docker;Linux;...|                null|Straight / Hetero...|      Yes|  Yes, somewhat|Less than once pe...|A few times per m...|                Easy|           Too short|   No|Computer science,...|  Django;Ruby on Rails|       Ruby on Rails|Just as welcome n...|       null|       15|           8|
# |         6|I am a developer ...|      No|        14|    null|     null|         null|           Germany|       European Euro|           EUR|                  null|                null|Designer;Develope...|Secondary school ...|  Employed full-time|White or of Europ...|   Man|Diversity of the ...|  Slightly satisfied|I am not interest...|  HTML/CSS;Java;Jav...|HTML/CSS;Java;Jav...|                  null|                null|                Github;Slack|    Confluence;Github...| Not sure|               null|    Fairly important|                null|                null|         Once a year|         No|                  No|           No|               Never|Ask developers I ...|           Amused|Stack Overflow (p...|Play games;Visit ...|    Windows|                null|               Android|Android;Docker;Wo...|I have some influ...|Straight / Hetero...|      Yes|  Yes, somewhat|A few times per m...|A few times per week|Neither easy nor ...|Appropriate in le...| null|                null|              React.js|                null|                null|       null|        6|           4|
# |         7|I am a developer ...|     Yes|        18| Monthly|     null|         null|             India|United States dollar|           USD|                  null|                null|Developer, back-e...|Bachelor’s degree...|  Employed full-time|                null|  null|                null|      Very satisfied|I’m not actively ...|       C#;HTML/CSS;PHP|     C#;HTML/CSS;PHP|                  null|                null|                        null|                    null|      Yes|Extremely important|      Very important|Better compensati...|Read company medi...|    Every few months|        Yes|                 Yes|           No|Sometimes: 1-2 da...|Start a free tria...|             null|Stack Overflow (p...|                null|    Windows|  20 to 99 employees|                  null|                null|                null|                null|      Yes|Yes, definitely|Multiple times pe...|Multiple times pe...|                null|                null| null|Computer science,...|                  null|                null|A lot more welcom...|       null|        6|           4|
# |         8|I am a developer ...|     Yes|        12|  Yearly| 116000.0|     116000.0|     United States|United States dollar|           USD|               MongoDB| MariaDB;MySQL;Redis|Developer, back-e...|Bachelor’s degree...|  Employed full-time|White or of Europ...|   Man|Remote work optio...|Slightly dissatis...|I’m not actively ...|            JavaScript|          Python;SQL|              Unity 3D|             Ansible|                        null|    Confluence;Jira;G...|      Yes|Extremely important|Not at all import...|Curious about oth...|Read company medi...|         Once a year|   Not sure|                 Yes|           No|Occasionally: 1-2...|Start a free tria...|Hello, old friend|Stack Overflow (p...|Play games;Call a...|Linux-based|  20 to 99 employees|  iOS;Slack Apps an...|              Docker|I have some influ...|Straight / Hetero...|      Yes| No, not really|Less than once pe...|Multiple times pe...|                Easy|Appropriate in le...|   No|Computer science,...|  Django;React.js;V...|               Flask|Just as welcome n...|       39.0|       17|          13|
# |         9|I am a developer ...|      No|        20|    null|     null|         null|           Tunisia|United States dollar|           USD|                  null|                null|Developer, full-s...|Professional degr...|Independent contr...|                null|   Man|Diversity of the ...|   Very dissatisfied|I’m not actively ...|           Python;Rust|HTML/CSS;JavaScri...|                  null|                null|                        null|    Github;Slack;Trel...|     null|               null|      Very important|Curious about oth...|                null|         Once a year|         No|                 Yes|           No|Occasionally: 1-2...|  Start a free trial|Hello, old friend|Stack Overflow (p...|            Meditate|    Windows|Just me - I am a ...|                  null|           WordPress|                null|Straight / Hetero...|      Yes|Yes, definitely|Multiple times pe...|Multiple times pe...|Neither easy nor ...|Appropriate in le...|   No|Computer science,...|            Angular.js|              jQuery|Just as welcome n...|       50.0|        6|           4|
# |        10|I am a developer ...|     Yes|        14|  Yearly|  25000.0|      32315.0|    United Kingdom|      Pound sterling|           GBP|  Microsoft SQL Server|Microsoft SQL Server|Database administ...|Master’s degree (...|  Employed full-time|White or of Europ...|   Man|Flex time or a fl...|      Very satisfied|I’m not actively ...|  HTML/CSS;Java;Jav...|HTML/CSS;Java;Jav...|     Pandas;TensorFlow|              Pandas|        Github;Microsoft ...|    Github;Microsoft ...|       No|            Neutral|    Fairly important|Curious about oth...|Company reviews f...|    Every few months|        Yes|Onboarding? What ...|           No|Often: 1-2 days p...|Start a free tria...|Hello, old friend|Stack Overflow (p...|Visit Stack Overflow|    Windows|    2 to 9 employees|  Android;Linux;Ras...|Android;Linux;Ras...|I have a great de...|Straight / Hetero...|      Yes|Yes, definitely|Multiple times pe...|Multiple times pe...|                Easy|Appropriate in le...|   No|Mathematics or st...|          Flask;jQuery|        Flask;jQuery|Somewhat more wel...|       36.0|        8|           4|
# |        11|I am a developer ...|     Yes|        13|  Yearly|  31000.0|      40070.0|    United Kingdom|      Pound sterling|           GBP|  Firebase;MongoDB;...|Firebase;MongoDB;...|Developer, back-e...|Bachelor’s degree...|  Employed full-time|White or of Europ...|   Man|Flex time or a fl...|Slightly dissatis...|I am actively loo...|  Go;JavaScript;Swi...| C#;JavaScript;Swift|  Node.js;React Native|             Node.js|        Jira;Github;Slack...|    Confluence;Jira;G...|       No|Extremely important|      Very important|Curious about oth...|Read company medi...|    Every few months|         No|                 Yes|           No|Rarely: 1-2 days ...|                null|          Annoyed|Stack Overflow (p...|Play games;Call a...|    Windows|10,000 or more em...|  AWS;Docker;iOS;MacOS|      AWS;Heroku;iOS|I have little or ...|Straight / Hetero...|      Yes|  Yes, somewhat|I have never part...|Multiple times pe...|                Easy|Appropriate in le...|   No|Computer science,...|  Angular;Django;Re...|Angular;Angular.j...|Just as welcome n...|       40.0|       10|           2|
# |        12|I am a developer ...|      No|        42| Monthly|   1100.0|      14268.0|             Spain|       European Euro|           EUR|                  null|                null|Designer;Develope...|Some college/univ...|  Employed full-time|White or of Europ...|   Man|Remote work optio...|   Very dissatisfied|I’m not actively ...|   HTML/CSS;JavaScript| HTML/CSS;JavaScript|                  .NET|                .NET|                      Github|                  Github| Not sure|            Neutral|  Somewhat important| Better compensation|Personal network ...|Once every few years|   Not sure|                  No|           No|Rarely: 1-2 days ...|                null|      Indifferent|Stack Overflow (p...|Visit Stack Overflow|    Windows|    2 to 9 employees|     Windows;WordPress|   Windows;WordPress|I have little or ...|Straight / Hetero...|      Yes|  Yes, somewhat|A few times per week|Multiple times pe...|                Easy|Appropriate in le...|   No|Mathematics or st...|        ASP.NET;jQuery|      ASP.NET;jQuery|Just as welcome n...|       40.0|        7|           7|
# |        13|I am not primaril...|     Yes|        14| Monthly|   3000.0|      38916.0|       Netherlands|       European Euro|           EUR|                  null|                null|Designer;Develope...|Secondary school ...|  Employed full-time|White or of Europ...|   Man|Industry that I’d...|      Very satisfied|I am not interest...|                Python| C;JavaScript;Python|                  null|                null|                        null|                    null|       No|               null|Not at all import...|Having a bad day ...|Read company medi...|Once every few years|         No|                 Yes|           No|Rarely: 1-2 days ...|  Start a free trial|           Amused|Stack Overflow (p...|Call a coworker o...|      MacOS|    2 to 9 employees|   Linux;MacOS;Windows|       MacOS;Windows|I have some influ...|Straight / Hetero...|      Yes|Yes, definitely|Multiple times pe...|Multiple times pe...|Neither easy nor ...|            Too long|   No|                null|                  null|                null|A lot less welcom...|       36.0|       35|          20|
# |        14|I am a developer ...|     Yes|        13|  Yearly|  66000.0|      66000.0|     United States|United States dollar|           USD|  Firebase;Microsof...|Firebase;Microsof...|Developer, deskto...|Associate degree ...|  Employed full-time|White or of Europ...|   Man|Industry that I’d...|  Slightly satisfied|I’m not actively ...|  HTML/CSS;JavaScri...|HTML/CSS;JavaScri...|               Node.js|             Node.js|        Confluence;Jira;G...|    Confluence;Jira;G...|      Yes|Extremely important|  Somewhat important|Wanting to share ...|Read company medi...|    Every few months|         No|                 Yes|           No|Occasionally: 1-2...|                null|           Amused|Stack Overflow (p...|Call a coworker o...|    Windows|100 to 499 employees|  Google Cloud Plat...|Google Cloud Plat...|I have little or ...|Straight / Hetero...|      Yes|Yes, definitely|A few times per week|Multiple times pe...|Neither easy nor ...|Appropriate in le...|   No|Computer science,...|        Angular;Vue.js|      Angular;Vue.js|Just as welcome n...|       40.0|        5|           1|
# |        15|I am a student wh...|     Yes|        13|    null|     null|         null|            France|                null|          null|                  null|        MySQL;Oracle|                null|Bachelor’s degree...|             Student|                null|   Man|Languages, framew...|                null|I’m not actively ...|  Assembly;Bash/She...|Bash/Shell/PowerS...|                  null|                null|               Github;Gitlab|                  Github|     null|               null|                null|                null|                null|Once every few years|        Yes|                null|           No|                null|Ask developers I ...|          Annoyed|Stack Overflow (p...|Play games;Visit ...|Linux-based|                null|                 Linux|               Linux|                null|      Gay or Lesbian|       No| No, not really|                null|A few times per m...|                Easy|Appropriate in le...|   No|Computer science,...|                  null|                null|Just as welcome n...|       null|        4|        null|
# |        16|I am a developer ...|     Yes|         8| Monthly|   7000.0|     108576.0|    United Kingdom|      Pound sterling|           GBP|                  null|          PostgreSQL|Database administ...|Bachelor’s degree...|Independent contr...|White or of Europ...|   Man|Industry that I’d...|      Very satisfied|I’m not actively ...|                    Go|Bash/Shell/PowerS...|                  null|                null|                        null|    Github;Slack;Goog...|       No|Extremely important|    Fairly important|Having a bad day ...|Personal network ...|         Once a year|   Not sure|                 Yes|           No|Often: 1-2 days p...|Ask developers I ...|Hello, old friend|Stack Overflow (p...|Visit Stack Overf...|      MacOS|Just me - I am a ...|                  null|AWS;Docker;Google...|                null|Straight / Hetero...|      Yes|  Yes, somewhat|Multiple times pe...|Multiple times pe...|                Easy|Appropriate in le...|   No|Computer science,...|                  null|     jQuery;React.js|Just as welcome n...|       50.0|       37|          23|
# |        17|I am a developer ...|     Yes|        14|  Yearly|  79000.0|      79000.0|     United States|United States dollar|           USD|  Cassandra;Elastic...|Microsoft SQL Ser...|Developer, full-s...|Bachelor’s degree...|  Employed full-time|White or of Europ...|   Man|Industry that I’d...|Slightly dissatis...|I’m not actively ...|  C#;Go;Haskell;HTM...|C#;HTML/CSS;JavaS...|    .NET Core;Teraform|        .NET;Node.js|        Github;Gitlab;Sla...|    Github;Gitlab;Sla...|      Yes|Extremely important|    Fairly important|Having a bad day ...|Company reviews f...|         Once a year|   Not sure|                  No|           No|Rarely: 1-2 days ...|                null|Hello, old friend|Stack Overflow (p...|Call a coworker o...|    Windows|  20 to 99 employees|  Docker;Kubernetes...|                null|I have little or ...|Straight / Hetero...|      Yes| No, not at all|I have never part...|Daily or almost d...|                Easy|Appropriate in le...|   No|Computer science,...|  ASP.NET Core;Gats...|ASP.NET;Gatsby;jQ...|Just as welcome n...|       40.0|        7|           3|
# |        18|I am a developer ...|     Yes|        12| Monthly| 105000.0|    1260000.0|     United States|United States dollar|           USD|  Elasticsearch;Pos...|Elasticsearch;Mar...| Developer, back-end|Bachelor’s degree...|  Employed full-time|White or of Europ...|   Man|Languages, framew...|      Very satisfied|I am not interest...|         HTML/CSS;Perl|Bash/Shell/PowerS...|                  null|                null|                      Github|            Github;Slack| Not sure|            Neutral|      Very important| Looking to relocate|                null|Once every few years|        Yes|Onboarding? What ...|          Yes|Occasionally: 1-2...|Start a free tria...|Hello, old friend|Stack Overflow (p...|Play games;Visit ...|Linux-based|100 to 499 employees|                 Linux|           AWS;Linux|I have some influ...|Straight / Hetero...|      Yes|  Yes, somewhat|I have never part...|Daily or almost d...|Neither easy nor ...|Appropriate in le...|   No|Computer science,...|                  null|                null|Just as welcome n...|       45.0|       19|          12|
# |        19|I am a developer ...|      No|        15|  Yearly|  83400.0|      83400.0|     United States|United States dollar|           USD|       MariaDB;MongoDB|MariaDB;Microsoft...|Developer, full-s...|Bachelor’s degree...|  Employed full-time|White or of Europ...|   Man|Flex time or a fl...|Slightly dissatis...|I’m not actively ...|  C#;Go;Python;Type...|Bash/Shell/PowerS...|  Node.js;React Nat...|.NET;.NET Core;No...|                Github;Slack|    Confluence;Jira;G...|      Yes|Extremely important|    Fairly important|Having a bad day ...|Company reviews f...|         Once a year|        Yes|                  No|           No|Occasionally: 1-2...|                null|Hello, old friend|Stack Overflow (p...|Call a coworker o...|    Windows|10,000 or more em...|  iOS;Slack Apps an...|             Windows|I have little or ...|Straight / Hetero...|      Yes|        Neutral|Less than once pe...|A few times per week|                Easy|Appropriate in le...|   No|Computer science,...|  Django;Express;Re...|Angular;Angular.j...|Just as welcome n...|       35.0|        9|           3|
# |        20|I am a developer ...|     Yes|        18|    null|     null|         null|             Spain|       European Euro|           EUR|                  null|IBM DB2;MariaDB;M...|Developer, deskto...|Bachelor’s degree...|  Employed full-time|Hispanic or Latin...|   Man|                null|Neither satisfied...|I’m not actively ...|                    Go| Java;JavaScript;SQL|            TensorFlow|             Node.js|                      Github|             Jira;Github|      Yes|            Neutral|      Very important|Having a bad day ...|Personal network ...|Once every few years|   Not sure|                  No|           No|Often: 1-2 days p...|                null|Hello, old friend|Stack Overflow (p...|Meditate;Call a c...|    Windows|100 to 499 employees|                  null|Heroku;Linux;Windows|I have little or ...|Straight / Hetero...|      Yes|  Yes, somewhat|A few times per m...|Multiple times pe...|                Easy|           Too short|   No|Another engineeri...|                Spring|   Angular.js;Spring|Just as welcome n...|       50.0|       22|          17|
# +----------+--------------------+--------+----------+--------+---------+-------------+------------------+--------------------+--------------+----------------------+--------------------+--------------------+--------------------+--------------------+--------------------+------+--------------------+--------------------+--------------------+----------------------+--------------------+----------------------+--------------------+----------------------------+------------------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+-----------+--------------------+-------------+--------------------+--------------------+-----------------+--------------------+--------------------+-----------+--------------------+----------------------+--------------------+--------------------+--------------------+---------+---------------+--------------------+--------------------+--------------------+--------------------+-----+--------------------+----------------------+--------------------+--------------------+-----------+---------+------------+
# only showing top 20 rows

# %% [markdown]
# ### Zapis wyników

# %%
df2 = df.withColumn ("Bonus", col("ConvertedComp") + 1000).filter("ConvertedComp is not NULL")   # dodaj kolumne  i zapisz do nowego DF

# %%
output_path = 'file:///home/jovyan/data/out.csv'
df2.write.format("csv").mode("overwrite").save(output_path)

# %%
spark.stop()
