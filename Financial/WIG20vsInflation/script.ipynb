# %%
import numpy as np
import pandas as pd
import yfinance as yf
import datetime as dt

import matplotlib.pyplot as plt

# %%
inflation = pd.read_csv("EU_Inflation_HICP_data.csv")
inflation['date'] = inflation['Unnamed: 0']
inflation.drop(columns='Unnamed: 0', inplace=True)
inflation = inflation[['date','Poland',]]

WIG20 = pd.read_csv("wig20_m.csv")
month = dict({1:'Jan', 2:'Feb', 3:'Mar', 4:'Apr', 5:'May', 6:'Jun', 7:'Jul', 8:'Aug', 9:'Sep', 10:'Sep', 11:'Nov', 12:'Dec'})
for i in range(len(WIG20)):
    date = dt.datetime.strptime(WIG20['Data'][i], "%Y-%m-%d")
    newdate = str(date.year)+str(month[date.month])
    WIG20.loc[i,'date'] = newdate

WIG20 = WIG20[['date','Zamkniecie']]

data = pd.merge(WIG20, inflation[['date','Poland']], on='date')
data = data.iloc[140:]
data
# Out:
#         date  Zamkniecie  Poland
# 140  2002Dec     1175.64     0.8
# 141  2003Jan     1115.87     0.3
# 142  2003Feb     1099.69     0.3
# 143  2003Mar     1093.50     0.4
# 144  2003Apr     1111.45     0.1
# ..       ...         ...     ...
# 374  2022Jun     1695.97    14.2
# 375  2022Jul     1721.11    14.2
# 376  2022Aug     1528.22    14.8
# 377  2022Sep     1377.91    15.7
# 378  2022Sep     1536.28    15.7
#
# [239 rows x 3 columns]

# %%
plt.figure(figsize=(20,10))
plt.plot(data['Poland'])
plt.plot(data['Zamkniecie']/500)

# %% [markdown]
# # Conclusioon
# bad = decrese in WIG
#
# good = increaase in WIG
#
# * too big inflation is bad
# * too smll inflation is bad
#
# abs(inflation - optimalInflatino) = 0 -> optimal WIG goes up
#
# the grather abs(inflation - optimalInflatino), worse the WIG
