# %%
import myTA
import numpy as np
import pandas as pd
import yfinance as yf
import datetime as dt
import matplotlib.pyplot as plt
# Out:
# c:\Users\QbaSo\AppData\Local\Programs\Python\Python39\lib\site-packages\requests\__init__.py:102: RequestsDependencyWarning: urllib3 (1.26.9) or chardet (5.1.0)/charset_normalizer (2.0.12) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({})/charset_normalizer ({}) doesn't match a supported "

# %%
code = "USDEUR=X"
data = myTA.downloadAndMakeAnalysis(code, dt.datetime(2022,1,1), dt.datetime.now(),'1h')
myTA.plotAnalysis(data, code, [])

tradesList = myTA.TradingStrategies.simpleMACDLookahed(data)
print( f"simpleMACDLookahed score: ${myTA.calculateProfit(tradesList, 0)}")

tradesList = myTA.TradingStrategies.simpleMACD(data)
print( f"simpleMACD score: ${myTA.calculateProfit(tradesList, 0)}")

tradesList = myTA.TradingStrategies.simpleMACDNoLossOnTrade(data)
print( f"simpleMACDNoLossOnTrade score: ${myTA.calculateProfit(tradesList, 0)}")

tradesList = myTA.TradingStrategies.simpleMACDZeroHistPrediction(data)
print( f"simpleMACDZeroHistPrediction score: ${myTA.calculateProfit(tradesList, 0)}")

tradesList = myTA.TradingStrategies.simpleMACDZeroHistPredictionNoLoss(data)
print( f"simpleMACDZeroHistPredictionNoLoss score: ${myTA.calculateProfit(tradesList, 0)}")

tradesList = myTA.TradingStrategies.simpleMACDOpenClose(data)
print( f"simpleMACDOpenClose score: ${myTA.calculateProfit(tradesList, 0)}")
# Out:
# simpleMACDLookahed score: $0.28479939699172974
# simpleMACD score: $-0.20670026540756226
# simpleMACDNoLossOnTrade score: $0.12279987335205078
# simpleMACDZeroHistPrediction score: $-0.1514011025428772
# simpleMACDZeroHistPredictionNoLoss score: $0.05119985342025757
# simpleMACDOpenClose score: $-0.11280161142349243
