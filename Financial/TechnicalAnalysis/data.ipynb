# %%
import talib as ta
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pandas_datareader as web
import datetime as dt
import mplfinance as mpf
import yfinance as yf
from myTA import downloadAndMakeAnalysis, makeAnalysis, plotAnalysis, Portfolio, Trade, calculateProfit, TradingStrategies
# Out:
# c:\Users\QbaSo\AppData\Local\Programs\Python\Python39\lib\site-packages\requests\__init__.py:102: RequestsDependencyWarning: urllib3 (1.26.9) or chardet (5.1.0)/charset_normalizer (2.0.12) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({})/charset_normalizer ({}) doesn't match a supported "

# %%
tickers = pd.read_csv("nasdaqTickers.csv")

# %%
tickers
# Out:
#      Symbol                                               Name Last Sale  \
# 0         A             Agilent Technologies Inc. Common Stock   $149.65
# 1        AA                    Alcoa Corporation Common Stock     $45.47
# 2       AAC  Ares Acquisition Corporation Class A Ordinary ...    $10.07
# 3      AACG   ATA Creativity Global American Depositary Shares   $1.2733
# 4      AACI            Armada Acquisition Corp. I Common Stock    $10.12
# ...     ...                                                ...       ...
# 8053   ZVSA             ZyVersa Therapeutics Inc. Common Stock     $1.57
# 8054    ZWS  Zurn Elkay Water Solutions Corporation Common ...    $21.15
# 8055   ZYME                        Zymeworks Inc. Common Stock     $7.86
# 8056   ZYNE          Zynerba Pharmaceuticals Inc. Common Stock     $0.53
# 8057   ZYXI                            Zynex Inc. Common Stock    $13.91
#
#       Net Change % Change    Market Cap        Country  IPO Year   Volume  \
# 0        -1.4400  -0.953%  4.430718e+10  United States    1999.0   699759
# 1        -1.0900  -2.341%  8.045333e+09            NaN    2016.0  3584741
# 2        -0.0200  -0.198%  1.258750e+09            NaN    2021.0   213355
# 3        -0.0767  -5.681%  3.995223e+07          China    2008.0    14435
# 4         0.0200   0.198%  2.095801e+08  United States    2021.0    20672
# ...          ...      ...           ...            ...       ...      ...
# 8053      0.0200    1.29%  1.425862e+07  United States    2022.0    45625
# 8054     -0.6600  -3.026%  3.760356e+09  United States    2012.0   890354
# 8055      0.0500    0.64%  4.951510e+08  United States       NaN   362492
# 8056     -0.0369  -6.509%  2.494324e+07  United States    2015.0   470618
# 8057      0.0400   0.288%  5.355350e+08  United States       NaN   235576
#
#                       Sector  \
# 0                Industrials
# 1                Industrials
# 2                    Finance
# 3     Consumer Discretionary
# 4                Industrials
# ...                      ...
# 8053             Health Care
# 8054               Utilities
# 8055             Health Care
# 8056             Health Care
# 8057             Health Care
#
#                                                Industry
# 0                                   Electrical Products
# 1                                    Metal Fabrications
# 2                                     Business Services
# 3                        Service to the Health Industry
# 4                       Consumer Electronics/Appliances
# ...                                                 ...
# 8053         Biotechnology: Pharmaceutical Preparations
# 8054                             Environmental Services
# 8055  Biotechnology: Biological Products (No Diagnos...
# 8056         Biotechnology: Pharmaceutical Preparations
# 8057                              Other Pharmaceuticals
#
# [8058 rows x 11 columns]

# %% [markdown]
# # Download a lot of historical data

# %%
delisted = []

for i in range(10):
    code=tickers['Symbol'][i]
    try:
        df = downloadAndMakeAnalysis(code, dt.datetime(1980,1,1), dt.datetime.now(),'1d').reset_index()
        df.to_csv(f"E:/Datasets/Stock/{code}.csv")
    except:
        delisted.append(i)
# Out:
# 1 Failed download:
# - AAIC^B: No data found, symbol may be delisted
#
# 1 Failed download:
# - AAIC^C: No data found, symbol may be delisted

# %%
df
# Out:
#           Date       Open       High        Low      Close  Adj Close  Volume  \
# 0   2021-07-19  24.750000  24.790001  24.600000  24.740000  22.856573   89600
# 1   2021-07-20  24.850000  24.850000  24.650000  24.757000  22.872280   16800
# 2   2021-07-21  24.799999  24.799999  24.730000  24.770000  22.884289   36700
# 3   2021-07-22  24.770000  24.799999  24.740000  24.770000  22.884289   24400
# 4   2021-07-23  24.780001  24.780001  24.730000  24.750000  22.865812   16900
# ..         ...        ...        ...        ...        ...        ...     ...
# 363 2022-12-23  23.459999  23.500000  23.440001  23.440001  23.440001     500
# 364 2022-12-27  23.179001  23.480000  23.179001  23.480000  23.480000     900
# 365 2022-12-28  23.490000  23.500000  23.490000  23.500000  23.500000    1500
# 366 2022-12-29  23.469999  23.469999  23.469999  23.469999  23.469999     300
# 367 2022-12-30  23.500000  23.500000  23.500000  23.500000  23.500000     500
#
#            RSI      macd  macd_signal  macd_hist     SMA200    SMA100
# 0          NaN       NaN          NaN        NaN        NaN       NaN
# 1          NaN       NaN          NaN        NaN        NaN       NaN
# 2          NaN       NaN          NaN        NaN        NaN       NaN
# 3          NaN       NaN          NaN        NaN        NaN       NaN
# 4          NaN       NaN          NaN        NaN        NaN       NaN
# ..         ...       ...          ...        ...        ...       ...
# 363  54.305627  0.032391    -0.011060   0.043451  23.955075  23.54138
# 364  55.097323  0.046205     0.000393   0.045812  23.947725  23.53818
# 365  55.512382  0.058097     0.011934   0.046163  23.941175  23.53358
# 366  54.695674  0.064359     0.022419   0.041940  23.934475  23.52908
# 367  55.402275  0.070925     0.032120   0.038805  23.927475  23.52438
#
# [368 rows x 13 columns]

# %%
df = downloadAndMakeAnalysis('AAIC^B', dt.datetime(1980,1,1), dt.datetime.now(),'1d').reset_index()
# Out:
# 1 Failed download:
# - AAIC^B: No data found, symbol may be delisted
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# c:\Users\QbaSo\Desktop\PyCode\financial\Algo\TechnicalAnalysis\data.ipynb Cell 7 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/QbaSo/Desktop/PyCode/financial/Algo/TechnicalAnalysis/data.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> df = downloadAndMakeAnalysis('AAIC^B', dt.datetime(1980,1,1), dt.datetime.now(),'1d').reset_index()
#
# File c:\Users\QbaSo\Desktop\PyCode\financial\Algo\TechnicalAnalysis\myTA.py:55, in downloadAndMakeAnalysis(ticker_code, start, end, interval)
#      53 def downloadAndMakeAnalysis(ticker_code, start, end, interval='1d'):
#      54     data = yf.download(ticker_code, start=start, end=end, interval=interval, progress=False)
# ---> 55     data['RSI'] = ta.RSI(data['Close'])
#      56     data['macd'], data['macd_signal'], data['macd_hist'] = ta.MACD(data['Close'])
#      57     data['SMA200'], data['SMA100'] = ta.SMA(data['Close'], 200), ta.SMA(data['Close'], 100)
#
# File c:\Users\QbaSo\AppData\Local\Programs\Python\Python39\lib\site-packages\talib\__init__.py:64, in _wrapper.<locals>.wrapper(*args, **kwds)
#      61     _args = args
#      62     _kwds = kwds
# ---> 64 result = func(*_args, **_kwds)
#      66 # check to see if we got a streaming result
#      67 first_result = result[0] if isinstance(result, tuple) else result
#
# File talib/_func.pxi:4377, in talib._ta_lib.RSI()
#
# File talib/_func.pxi:68, in talib._ta_lib.check_begidx1()
#
# Exception: inputs are all NaN
