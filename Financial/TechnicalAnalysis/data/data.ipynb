# %%
import talib as ta
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pandas_datareader as web
import datetime as dt
import mplfinance as mpf
import yfinance as yf
# from myTA import downloadAndMakeAnalysis, makeAnalysis, plotAnalysis, Portfolio, Trade, calculateProfit, TradingStrategies

# %%
tickers = pd.read_csv("nasdaqTickers.csv")

# %%
tickers
# Out:
#      Symbol                                               Name Last Sale  \
# 0         A             Agilent Technologies Inc. Common Stock   $149.65
# 1        AA                    Alcoa Corporation Common Stock     $45.47
# 2       AAC  Ares Acquisition Corporation Class A Ordinary ...    $10.07
# 3      AACG   ATA Creativity Global American Depositary Shares   $1.2733
# 4      AACI            Armada Acquisition Corp. I Common Stock    $10.12
# ...     ...                                                ...       ...
# 8053   ZVSA             ZyVersa Therapeutics Inc. Common Stock     $1.57
# 8054    ZWS  Zurn Elkay Water Solutions Corporation Common ...    $21.15
# 8055   ZYME                        Zymeworks Inc. Common Stock     $7.86
# 8056   ZYNE          Zynerba Pharmaceuticals Inc. Common Stock     $0.53
# 8057   ZYXI                            Zynex Inc. Common Stock    $13.91
#
#       Net Change % Change    Market Cap        Country  IPO Year   Volume  \
# ...

# %%
tickers.sort_values('Market Cap', ascending=False)
# Out:
#       Symbol                                               Name Last Sale  \
# 19      AAPL                            Apple Inc. Common Stock   $129.93
# 4830    MSFT                 Microsoft Corporation Common Stock   $239.82
# 3225    GOOG                Alphabet Inc. Class C Capital Stock    $88.73
# 3226   GOOGL                 Alphabet Inc. Class A Common Stock    $88.23
# 443     AMZN                       Amazon.com Inc. Common Stock    $84.00
# ...      ...                                                ...       ...
# 7882   WRB^G  W.R. Berkley Corporation 4.25% Subordinated De...    $18.52
# 7883   WRB^H  W.R. Berkley Corporation 4.125% Subordinated D...    $17.73
# 7895   WSO/B                                        Watsco Inc.   $252.51
# 7941  XFLT^A  XAI Octagon Floating Rate & Alternative Income...  $25.1999
# 7981  YCBD^A  cbdMD Inc. 8.0% Series A Cumulative Convertibl...     $4.05
#
#       Net Change % Change    Market Cap        Country  IPO Year    Volume  \
# ...

# %% [markdown]
# # Stocks by Sector

# %%
Sectors = tickers['Sector'].unique()[0:3]
topTickers = pd.DataFrame()

for sector in Sectors:
    topTickers = pd.concat([topTickers, tickers[tickers['Sector'] == sector].sort_values(by='Volume', ascending=False).head(3)])

# %%
topTickers
# Out:
#      Symbol                                              Name Last Sale  \
# 5077   NKLA                   Nikola Corporation Common Stock     $2.16
# 5065   NILE                BitNile Holdings Inc. Common Stock   $0.1225
# 2950   FUBO                          fuboTV Inc. Common Stock     $1.74
# 810     BAC          Bank of America Corporation Common Stock    $33.12
# 6760   SOFI             SoFi Technologies Inc. Common Stock       $4.61
# 2961   FUTU  Futu Holdings Limited American Depositary Shares    $40.65
# 4892   MULN               Mullen Automotive Inc. Common Stock    $0.286
# 7325   TSLA                           Tesla Inc. Common Stock   $123.18
# 443    AMZN                      Amazon.com Inc. Common Stock    $84.00
#
#       Net Change  % Change    Market Cap        Country  IPO Year     Volume  \
# 5077     -0.2300   -9.623%  1.034318e+09  United States    2018.0   15201702
# 5065      0.0225    22.50%  4.477684e+07  United States    1997.0   13138275
# ...

# %% [markdown]
# # Download a lot of historical data

# %%
delisted = []

for i in range(10):
    code=tickers['Symbol'][i]
    try:
        df = downloadAndMakeAnalysis(code, dt.datetime(1980,1,1), dt.datetime.now(),'1d').reset_index()
        df.to_csv(f"E:/Datasets/Stock/{code}.csv")
    except:
        delisted.append(i)

# %%
df
# Out:
#      Symbol                                               Name Last Sale  \
# 4892   MULN                Mullen Automotive Inc. Common Stock    $0.286
# 7325   TSLA                            Tesla Inc. Common Stock   $123.18
# 443    AMZN                       Amazon.com Inc. Common Stock    $84.00
# 5070    NIO  NIO Inc. American depositary shares each  repr...     $9.75
# 2631      F                    Ford Motor Company Common Stock    $11.63
# ...     ...                                                ...       ...
# 6977  SWAGW                       Stran & Company Inc. Warrant   $0.1498
# 4069  KELYB           Kelly Services Inc. Class B Common Stock    $17.26
# 1402    CCZ                             Comcast Holdings ZONES    $56.64
# 7851   WLYB                John Wiley & Sons Inc. Common Stock    $39.23
# 146   ADTHW           AdTheorent Holding Company Inc. Warrants     $0.10
#
#       Net Change % Change    Market Cap        Country  IPO Year     Volume  \
# ...

# %%
df = downloadAndMakeAnalysis('AAIC^B', dt.datetime(1980,1,1), dt.datetime.now(),'1d').reset_index()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\QbaSo\Desktop\PyCode\financial\Algo\TechnicalAnalysis\data\data.ipynb Cell 11 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/QbaSo/Desktop/PyCode/financial/Algo/TechnicalAnalysis/data/data.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> df = downloadAndMakeAnalysis('AAIC^B', dt.datetime(1980,1,1), dt.datetime.now(),'1d').reset_index()
#
# NameError: name 'downloadAndMakeAnalysis' is not defined
