# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import datetime

# %%
for _ in range(100):
    url = "https://www.bankier.pl/new-charts/get-data?symbol=KGHM&intraday=false&type=area&max_period=true"
    r = requests.get(url)
    print(r.status_code)
# Out:
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200

# %%
dt = datetime.datetime.fromtimestamp(int(data[0,0])/1000)

# %%
date = [datetime.datetime.fromtimestamp(int(data[i,0])/1000) for i in range(len(data))]

# %%
data = np.array(r.json()['navigator'])

# %%
plt.plot(date, data[:,1])
